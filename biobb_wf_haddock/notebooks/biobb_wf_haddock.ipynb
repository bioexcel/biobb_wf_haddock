# %% [markdown]
# # Haddock3 Protein-Protein Docking using HADDOCK3 with BioExcel Building Blocks (biobb)
# **Based on the official [HADDOCK3 antibody-antigen modelling tutorial](https://www.bonvinlab.org/education/HADDOCK3/HADDOCK3-antibody-antigen/).**
#
# ***
# This tutorial aims to illustrate the process of **proptein protein docking**, step by step, using **Haddock3** with the **BioExcel Building Blocks library (biobb)**. The particular systems used in this tutorial are the **Interleukin-1β (IL-1β) antigen** (PDB code 4I1B, https://doi.org/10.2210/pdb4I1B/pdb) and the **gevokizumab antibody** (PDB code 4G6K, https://doi.org/10.2210/pdb4G6K/pdb). The complex is also available under the PDB code 4G6M, https://doi.org/10.2210/pdb4G6M/pdb.
#
# ***
#
# **Biobb modules** used:
#
# * [biobb_io](https://github.com/bioexcel/biobb_io): Tools to fetch biomolecular data from public databases.
# * [biobb_pdb_tools](https://github.com/bioexcel/biobb_pdb_tools): Swiss army knife for manipulating and editing PDB files.
# * [biobb_haddock](https://github.com/bioexcel/biobb_haddock): Module collection to compute information-driven flexible protein-protein docking.
#
# **Auxiliary libraries** used:
#
# * [jupyter](https://jupyter.org/): Free software, open standards, and web services for interactive computing across all programming languages.
# * [nglview](http://nglviewer.org/#nglview): Jupyter/IPython widget to interactively view molecular structures and trajectories in notebooks.
#
# ### Conda Installation and Launch
#
# ```console
# git clone https://github.com/bioexcel/biobb_wf_haddock.git
# cd biobb_wf_haddock
# conda env create -f conda_env/environment.yml
# conda activate biobb_wf_haddock
# jupyter-notebook biobb_wf_haddock/notebooks/biobb_wf_haddock_aa.ipynb
#   ```
#
# ***
# ### Pipeline steps:
#  1. [Input Parameters](#Input-parameters)
#  2. [Preparing PDB files for docking](#Preparing-PDB-files-for-docking)
#     - [Fetching PDB structures](#Fetching-PDB-structures)
#     - [Preparing the antibody structure](#Preparing-the-antibody-structure)
#     - [Preparing the antigen structure](#Preparing-the-antigen-structure)
#     - [Preparing the reference structure](#Preparing-the-reference-structure)
#  3. [Defining HADDOCK3 restraints](#Defining-HADDOCK3-restraints)
#     - [Paratope Restraints](#Paratope-Restraints)
#     - [Epitope Restraints](#Epitope-Restraints)
#     - [HADDOCK3 passive restraints](#HADDOCK3-passive-restraints)
#     - [HADDOCK3 ambiguous restraints](#HADDOCK3-ambiguous-restraints)
#     - [Additional restraints for multi-chain proteins](#Additional-restraints-for-multi-chain-proteins)
#  4. [Docking](#Docking)
#     - [Create topology](#1.-Create-topology)
#     - [Rigid Body sampling](#2.-Rigid-Body-sampling)
#     - [1st CAPRI evaluation](#3.-1st-CAPRI-evaluation)
#     - [Select Top structures](#4.-Select-Top-structures)
#     - [Flexible Refinement](#5.-Flexible-Refinement)
#     - [2nd CAPRI evaluation](#6.-2nd-CAPRI-evaluation)
#     - [Energy minimization refinement](#7.-Energy-minimization-refinement)
#     - [3rd CAPRI evaluation](#8.-3rd-CAPRI-evaluation)
#     - [Clustering](#9.-Clustering)
#     - [Selecting top clusters](#10.-Selecting-top-clusters)
#     - [Final CAPRI evaluation](#11.-Final-CAPRI-evaluation)
#     - [Contacts analysis](#12.-Contacts-analysis)
#     - [Final Results](#13.-Final-Results)
#  5. [Questions & Comments](#Questions-&-Comments)
#
#
# ***
#
# <table cellspacing="0" cellpadding="0" style="border-collapse: collapse; width: 100%;">
#     <tr style="background: white;">
#         <td style="text-align: center; vertical-align: middle; width: 50%;">
#             <img src="https://bioexcel.eu/wp-content/uploads/2019/04/Bioexcell_logo_1080px_transp.png" alt="Bioexcel2 logo"
#             title="Bioexcel logo" width="400" />
#         </td>
#         <td style="text-align: center; vertical-align: middle; width: 50%;">
#             <img src="imgs/HADDOCK3-logo.png" alt="HADDOCK3" style="max-width: 100%; height: auto; display: block; margin: auto;">
#         </td>
#     </tr>
# </table>
#
# ***

# %% [markdown]
# ## Initializing colab
# The three cells below are used only in case this notebook is executed via **Google Colab**. Take into account that, for running conda on **Google Colab**, the **condacolab** library must be installed. As [explained here](https://pypi.org/project/condacolab/), the installation requires a **kernel restart**, so when running this notebook in **Google Colab**, don't run all cells until this **installation** is properly **finished** and the **kernel** has **restarted**.

# %%
# Only executed when using google colab
import sys
if 'google.colab' in sys.modules:
  # !git clone https://github.com/bioexcel/biobb_wf_haddock.git
  # !pip install -q condacolab
  import condacolab
  condacolab.install()

# %%
if 'google.colab' in sys.modules: 
  # Install conda environment
  # !mamba env update -n base -f biobb_wf_haddock/conda_env/environment.yml
  # Fix Python path to prioritize conda packages
  conda_path = '/usr/local'
  sys.path.insert(0, f'{conda_path}/lib/python3.11/site-packages')
  # Enable widgets for colab
  from google.colab import output 
  output.enable_custom_widget_manager() 
  # Change working dir
  import os 
  os.chdir("biobb_wf_haddock/biobb_wf_haddock/notebooks") 
  print(f"New working directory: {os.getcwd()}")

# %%
# Store original Colab paths
ORIGINAL_PATHS = [p for p in sys.path if '/usr/local/lib/python3.12' in p or 'dist-packages' in p]
CONDA_PATHS = [p for p in sys.path if '/usr/local/lib/python3.11' in p]

def use_colab_plotly():
    """Switch to Colab's original plotly"""
    # Move Colab paths to the front
    for path in reversed(ORIGINAL_PATHS):
        if path in sys.path:
            sys.path.remove(path)
        sys.path.insert(0, path)
    
    # Reload plotly and nbformat from Colab's environment
    if 'plotly' in sys.modules:
        del sys.modules['plotly']
        del sys.modules['plotly.graph_objs']
        # Delete all plotly submodules
        to_delete = [m for m in sys.modules if m.startswith('plotly')]
        for m in to_delete:
            del sys.modules[m]
    if 'nbformat' in sys.modules:
        del sys.modules['nbformat']

def use_conda_env():
    """Switch back to conda environment"""
    # Move conda paths to the front
    for path in reversed(CONDA_PATHS):
        if path in sys.path:
            sys.path.remove(path)
        sys.path.insert(0, path)
    
    # Clean up Colab's plotly/nbformat so conda versions load next time
    if 'plotly' in sys.modules:
        to_delete = [m for m in sys.modules if m.startswith('plotly')]
        for m in to_delete:
            del sys.modules[m]
    if 'nbformat' in sys.modules:
        del sys.modules['nbformat']

# %% [markdown]
# ## Helper functions
# Small **functions** used multiple times in the notebook and defined to make the code shorter and easier to follow.
# - ***biobb_global_properties***: initializes the global properties dictionary used by all the BioBBs, with the paths for the log files (log.out, log.err). Avoids ending up with a folder full of log files.
# - ***pdb_tools_pipeline***: launches a list of pdb_tools command line executions using the BioBB pdb_tools module.
# - ***display_actpass***: loads a PDB file into NGLview widget and adds HADDOCK3 active and passive residues with surface representation.
# - ***capri_visualization_models***: builds a dropdown to select specific models from the list of structures generated by HADDOCK.
# - ***superpose_ref***: superposes a PDB structure to a reference one.
# - ***superpose_models***: superposes multiple PDB structures to a reference one and writes a multi-model PDB file.
# - ***capri_visualization***: builds the NGL widget to show a 3D representation of the models generated by HADDOCK, with the possibility to select a specific model to represent.
# - ***open_results_mod***: opens a new tab in the web browser and loads a HADDOCK generated html file with summary results.

# %%
# Imports
import nglview as nv
import pytraj as pt
import ipywidgets
import webbrowser
import zipfile
import pandas
import glob
import os
import sys
import shutil

from Bio.PDB import PDBParser, PDBIO, CEAligner, Structure, Model, Chain
from IPython.display import display, Markdown
from jupyter_server.serverapp import list_running_servers
from biobb_common import biobb_global_properties

biobb_global_properties.update({
    'out_log_path': 'log/log.out',  # Define the folder and name for
    'err_log_path': 'log/log.err',  # output and error logs
    #'disable_sandbox': True,       # Disable the sandbox so input data is not copied
})

# All the inputs and outputs variables are also defined in the variables.py file
# in case you want to restart the notebook from another point
from variables import *

def pdb_tools_pipeline(inp_file, out_file, steps):
    """Helper function to concatenate calls to pdb_tools"""
    tmp_file = inp_file
    for step, props in steps:
        # Apply each step in the pipeline
        step(input_file_path  = tmp_file, 
             output_file_path = out_file, 
             properties       = props)
        tmp_file = 'tmp.pdb'
        os.rename(out_file, tmp_file)
    os.rename(tmp_file,out_file)

def display_actpass(pdb, actpass, opacity=1):
    with open(actpass, 'r') as file:
        actpass = file.read().splitlines()
        act_res = actpass[0].replace(' ', ', ')
        pas_res = actpass[1].replace(' ', ', ')

    # Load the PDB files
    view = nv.show_structure_file(pdb, default_representation=False)
    view.clear()
    view.add_cartoon(color='black')
    view.add_ball_and_stick(color='grey',opacity=opacity)
    view.add_surface(selection=f'not ( {pas_res}, {act_res} )', color='white', opacity=opacity)
    if act_res != '':
        view.add_surface(selection=f'{act_res}', color='red')
    if pas_res != '':
        view.add_surface(selection=f'{pas_res}', color='green', opacity=opacity)
    view.layout.width = '100%'
    view.center()
    return view

def step_backup(step):
    """Backup system in case you want to restart the workflow from a previous point."""
    backup = f'{out_path}/docking/step_backups/{step-1}'
    # Recover the backup
    if os.path.exists(backup):
        if os.path.exists(haddock_wf_data):
            shutil.rmtree(haddock_wf_data)
        shutil.copytree(backup, haddock_wf_data)
    # Backup the previous step
    if not os.path.exists(backup):
        shutil.copytree(haddock_wf_data, backup)
    # Remove the current step backup
    backup = f'{out_path}/docking/step_backups/{step}'
    if os.path.exists(backup):
        shutil.rmtree(backup)
        
def capri_visualization_models(tsv_dir,capri_out):

    models = []
    for i, m in enumerate(capri_out['model']):
        models.append(('Model Rank ' + str(i+1), os.path.normpath(os.path.join(tsv_dir, single_df['model'][i]))))
        
    mdsel = ipywidgets.Dropdown(
        options=models,
        description='Sel. model:',
        disabled=False,
    )
    
    # Dictionary of options in the dropdown
    options_dict = dict(mdsel.options)

    return mdsel

def superpose_ref(pdb_ref, pdb_to_sup, output_file, chain):

    # Parse the structures
    parser = PDBParser(QUIET=True)
    structure1 = parser.get_structure("pdb_ref", pdb_ref)
    structure2 = parser.get_structure("pdb_to_sup", pdb_to_sup)
    
    # Select only a portion of reference structure (e.g., Chain A )
    selected_residues = [res for res in structure1[0][chain]]
    
    # Create a new structure object with the selected residues
    selected_structure = Structure.Structure("selected_structure")
    model = Model.Model(0)
    chain = Chain.Chain("A")
    
    for res in selected_residues:
        chain.add(res)
    
    model.add(chain)
    selected_structure.add(model)    

    # Perform CE alignment using the selected region as reference
    aligner = CEAligner()
    aligner.set_reference(selected_structure)
    aligner.align(structure2)
    
    # Save structure2 to a PDB file
    io = PDBIO()
    io.set_structure(structure2)
    io.save(output_file)
    
def superpose_models(chain,input_path,output_file):
    
    pdb_files = sorted(glob.glob(f"{input_path}/*.pdb"))
    
    # Get all PDB files and sort them
    # Create a trajectory from the PDB files
    traj = pt.iterload(pdb_files, top=pdb_files[0])
    # Align the structures by chain and save the ensemble as a multi-model PDB
    pt.align(traj, ref=0, mask=f'::{chain}')
    traj.save(output_file, options="model", overwrite=True)

def capri_visualization(ensemble_A,ensemble_B,reference_A,reference_B,input_path,single_df,cluster_df):

    def on_dropdown_change(change):
        """Handle dropdown selection changes.
        From https://github.com/nglviewer/nglview/issues/765
        """
    
        if change['type'] == 'change' and change['name'] == 'value': 
            selected_file = change['new']
            if selected_file=='All':
                view1._remote_call('setSelection', target='compList', args=["*"], 
                   kwargs=dict(component_index=0))
                view2._remote_call('setSelection', target='compList', args=["*"], 
                   kwargs=dict(component_index=0))
            else:
                # Extract model number from the filename
                model_arr = selected_file.split('_')
                if (len(model_arr)) > 2:
                    cluster_num = int(model_arr[-3])
                    cluster_model_num = int(model_arr[-1])
                    model_num = (cluster_num * cluster_model_num) - 1
                else:
                    model_num = int(model_arr[-1]) - 1
                print(f"Selected model: {model_num}")
                # with open(f"{out_path}/example.txt", "w") as file:
                #     file.write(f"Hello: {model_num}")
                #     file.write(f"Dict: {dict(component_index=0)}")
                # Update the view with the selected model
                view1._remote_call('setSelection', target='compList', 
                                args=[f"/{model_num}"], 
                                kwargs=dict(component_index=0))
                # You can also update view2 if needed
                view2._remote_call('setSelection', target='compList', 
                                args=[f"/{model_num}"], 
                                kwargs=dict(component_index=0))

    # Create a dropdown widget
    pdb_files = sorted(glob.glob(f"{input_path}/*.pdb"))
    opts = ['All']
    opts.extend([pdb_file.split('/')[-1].split('.')[0] for pdb_file in pdb_files])
    mdsel = ipywidgets.Dropdown(
        options=opts,
        description='Sel. model:',
        disabled=False,
    )
    display(Markdown("#### Please select a model:"))
    display(mdsel)
    
    # Register the callback function
    mdsel.observe(on_dropdown_change, names='value')
    
    # Loading Ensemble aligned to chain A (Antibody)
    view1 = nv.show_structure_file(ensemble_A, default_representation=False)
    
    # Loading Ensemble aligned to chain B (Antigen)
    view2 = nv.show_structure_file(ensemble_B, default_representation=False)
    
    # Adding reference structure for comparison purposes
    view1.add_component(reference_A)
    view1.component_0.add_cartoon(color='cyan',opacity=.6)
    view2.add_component(reference_B)
    view2.component_0.add_cartoon(color='cyan',opacity=.6)
    
    # Colouring models aligned to chain A (Antibody: blue, Antigen: green) 
    view1.component_1.clear()
    view1.component_1.add_cartoon(selection=':A', color='purple')
    view1.component_1.add_cartoon(selection=':B', color='green')
    view1._remote_call('setSize', target='Widget', args=['500px','500px'])
    view1.layout.margin = "auto"
    view1.camera='orthographic'
    
    # Colouring models aligned to chain B (Antibody: blue, Antigen: green) 
    view2.component_1.clear()
    view2.component_1.add_cartoon(selection=':A', color='purple')
    view2.component_1.add_cartoon(selection=':B', color='green')
    view2._remote_call('setSize', target='Widget', args=['500px','500px'])
    view2.layout.margin = "auto"
    view2.camera='orthographic'
    
    # Display the viewer
    box = ipywidgets.HBox([view1, view2])
    display(Markdown("#### Generated models (left, aligned to chain A -Antibody-; right, aligned to chain B -Antigen-, cyan, reference)"))
    display(box)
    
    # Show CAPRI Evaluation values
    display(Markdown("#### CAPRI Evaluation values for Single Structure:"))
    display(Markdown("DockQ: incorrect (<0.23), acceptable (0.23-0.49), medium (0.49-0.80), and high (>=0.80)"))
    display(single_df.head(10))
    display(Markdown("#### CAPRI Evaluation values for Cluster-based output:"))
    display(cluster_df.head(10))

def open_results_mod(html_file):

    from IPython.display import HTML
    import shutil
    
    # Load the jupyter servers running
    servers = list(list_running_servers())
    
    if server := servers[0]:
        token = server.get("token")

        # Open the report file and modify accordingly
        with open(html_file, "r") as file:
            content = file.read()
        
        if 'id="banner"' not in content:
            banner = '<div id="banner" class="m-4" style="padding: 20px;font-weight: bold;background: #bde0ff;">To download a PDB file, please click the corresponding <b><i>Download</i></b> link with the <b><i>CTRL/COMMAND</i></b> key pressed</div><link href="https'
            content = content.replace('<link href="https', banner)
            content = content.replace("pdb.gz", f"pdb?token={token}")
            content = content.replace("..\\/", "..\\/..\\/")
        
            # Write the modified content back to the file
            with open(html_file, "w") as file:
                file.write(content)

        display(HTML(f'<a href="{html_file}" target="_blank">Click to open HADDOCK3 CAPRI evaluation report for this step</a>'))

    else:
        print("Could not determine the Jupyter Notebook port.")
# Out:
# /Users/gbayarri/miniconda3/envs/biobb_wf_haddock/lib/python3.12/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# ***
# ## Input parameters
# **Input parameters** needed:
#  - **antibody_pdb**: Antibody structure PDB code (in this case 4G6K)
#  - **antigen_pdb**: Antigen structure PDB code (in this case 4I1B)
#  - **complex_pdb**: Complex structure PDB code, if available (in this case 4G6M)
#  - **out_path**: Output folder where resulting files will be generated

# %%
antibody_pdb = '4G6K'
antigen_pdb = '4I1B'
complex_pdb = '4G6M' 
out_path = './data/antibody'

# %% [markdown]
# Creating **output folder hierarchy**:
# - ***out_path***
#     - ***pre***: *Initial data*
#     - ***docking***: *Docking results*

# %%
#os.makedirs('data',exist_ok=True)
os.makedirs(out_path,exist_ok=True)
os.makedirs(f'{out_path}/pre',exist_ok=True)
os.makedirs(f'{out_path}/docking',exist_ok=True)

# %% [markdown]
# ***
# # Preparing PDB files for docking
#
# Before initiating a docking process with **HADDOCK3**, the input PDB structures must meet a [**predefined set of requirements**](https://www.bonvinlab.org/haddock3-user-manual/structure_requirements.html#pdb-format). For example, each molecule should consist of a **single chain** with **non-overlapping residue numbering** within the same chain. Additionaly, **insertion codes** must be renumbered, an issue particularly problematic with antibodies, as often follow the Chothia numbering scheme and insertions created by this system (e.g. 82A, 82B, 82C) cannot be directly processed by **HADDOCK3**.
#
# References: <br>
#
# **ANARCI: antigen receptor numbering and receptor classification.**<br>
# *Dunbar J, Deane CM.*<br>
# *Bioinformatics, 2016;32(2):298-300.*<br>
# *Available at: https://doi.org/10.1093/bioinformatics/btv552*
# ***

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>IMPORTANT NOTE:</b> The preparation steps in this notebook were prepared for the specific systems used (<i>Interleukin-1β antigen, gevokizumab antibody</i>), which we know don't have issues such as <b>insertion codes</b> or <b>alternative locations</b>. Please consider using a more complete preparation pipeline for complex cases. Examples can be found in the <a href="https://www.bonvinlab.org/education/HADDOCK3/">HADDOCK3 official tutorials site</a>.
# </div>

# %% [markdown]
# ***
# ## Fetching PDB structures
# Downloading **PDB structures** from the [PDBe](https://www.ebi.ac.uk/pdbe/) database. Keeping only **standard residues** (removing heteroatoms). <br>
# Alternatively, local PDB files can be used as starting structures. <br>
# Downloading **three different files**:
# - **antibody**: Antibody protein structure
# - **antigen**: Antigen protein structure
# - **complex**: Antibody-antigen complex structure
#
# ***
# **Building Blocks** used:
#  - [Pdb](https://biobb-io.readthedocs.io/en/latest/api.html#module-api.pdb) from **biobb_io.api.pdb**
# ***

# %%
# Downloading desired PDB files
# Import module
from biobb_io.api.pdb import pdb

## Antibody PDB

# Create properties dict and inputs/outputs
ab_pdb  = f'{out_path}/pre/{antibody_pdb}_0.pdb'
ab_prop = {
    'pdb_code': antibody_pdb,
    'filter': ['ATOM', 'TER', 'END'],
}

# Create and launch bb
pdb(output_pdb_path = ab_pdb,  
    properties = ab_prop)

## Antigen PDB

# Create properties dict and inputs/outputs
ag_pdb  = f'{out_path}/pre/{antigen_pdb}_0.pdb'
ag_prop = {
    'pdb_code': antigen_pdb,
    'filter': ['ATOM', 'TER', 'END']
}

# Create and launch bb
pdb(output_pdb_path = ag_pdb,  
    properties = ag_prop)

## Complex PDB

# Create properties dict and inputs/outputs
cx_pdb = f'{out_path}/pre/{complex_pdb}_0.pdb'
cx_prop = {
    'pdb_code': complex_pdb,
    'filter': ['ATOM', 'TER', 'END']
}

# Create and launch bb
pdb(output_pdb_path = cx_pdb,  
    properties = cx_prop)
# Out:
# 2026-01-22 16:55:05,502 [MainThread  ] [INFO ]  Module: biobb_io.api.pdb Version: 5.2.0
# 2026-01-22 16:55:05,503 [MainThread  ] [INFO ]  Downloading 4g6k from: https://www.ebi.ac.uk/pdbe/entry-files/download/pdb4g6k.ent
# 2026-01-22 16:55:05,879 [MainThread  ] [INFO ]  Writting pdb to: ./data/antibody/pre/4G6K_0.pdb
# 2026-01-22 16:55:05,885 [MainThread  ] [INFO ]  Filtering lines NOT starting with one of these words: ['ATOM', 'TER', 'END']
# 2026-01-22 16:55:05,909 [MainThread  ] [INFO ]
# 2026-01-22 16:55:05,912 [MainThread  ] [INFO ]  Module: biobb_io.api.pdb Version: 5.2.0
# 2026-01-22 16:55:05,913 [MainThread  ] [INFO ]  Downloading 4i1b from: https://www.ebi.ac.uk/pdbe/entry-files/download/pdb4i1b.ent
# 2026-01-22 16:55:06,141 [MainThread  ] [INFO ]  Writting pdb to: ./data/antibody/pre/4I1B_0.pdb
# 2026-01-22 16:55:06,146 [MainThread  ] [INFO ]  Filtering lines NOT starting with one of these words: ['ATOM', 'TER', 'END']
# 2026-01-22 16:55:06,157 [MainThread  ] [INFO ]
# 2026-01-22 16:55:06,161 [MainThread  ] [INFO ]  Module: biobb_io.api.pdb Version: 5.2.0
# 2026-01-22 16:55:06,162 [MainThread  ] [INFO ]  Downloading 4g6m from: https://www.ebi.ac.uk/pdbe/entry-files/download/pdb4g6m.ent
# 2026-01-22 16:55:06,495 [MainThread  ] [INFO ]  Writting pdb to: ./data/antibody/pre/4G6M_0.pdb
# 2026-01-22 16:55:06,501 [MainThread  ] [INFO ]  Filtering lines NOT starting with one of these words: ['ATOM', 'TER', 'END']
# 2026-01-22 16:55:06,523 [MainThread  ] [INFO ]
# 0

# %% [markdown]
# ### Visualizing 3D structures
# Visualizing the downloaded **PDB structures** using **NGLview**:
# - Left: **Antibody**. Heavy Chain: Blue; Light Chain: Red.
# - Center: **Antigen** (Green)
# - Right: **Complex**. Antibody: Heavy Chain: Blue; Light Chain: Red; Antigen: Green.

# %%
# Show structures:
# Antibody
view1 = nv.show_structure_file(ab_pdb)
view1._remote_call('setSize', target='Widget', args=['350px','400px'])
view1.clear_representations()
view1.add_representation(repr_type='cartoon', selection=':H', color='blue')
view1.add_representation(repr_type='cartoon', selection=':L', color='red')
view1.camera='orthographic'
# Antigen
view2 = nv.show_structure_file(ag_pdb)
view2._remote_call('setSize', target='Widget', args=['350px','400px'])
view2.clear_representations()
view2.add_representation(repr_type='cartoon', selection='protein', color='green')
view2.camera='orthographic'
# Complex
view3 = nv.show_structure_file(cx_pdb)
view3._remote_call('setSize', target='Widget', args=['350px','400px'])
view3.clear_representations()
view3.add_representation(repr_type='cartoon', selection=':H', color='blue')
view3.add_representation(repr_type='cartoon', selection=':L', color='red')
view3.add_representation(repr_type='cartoon', selection=':A', color='green')
view3.camera='orthographic'
ipywidgets.HBox([view1, view2, view3])
# Out:
# HBox(children=(NGLWidget(), NGLWidget(), NGLWidget()))

# %% [markdown]
# ## Preparing the antibody structure
#
# The **gevokizumab antibody**  needs to be processed to select only the **Heavy** and **Light** chains and combine both into one single file with a **unified chain** and **segment id** and **residue numbering** starting at 1. Additionaly, only the **variable fragment (Fv)** of the antibody (see image) will be selected and used, to shorten the structure size and thus reduce the computation time.
#
# <div style="text-align: center;">
#     <img src="imgs/antigen.png" alt="antibody_image" width="400">
# </div>
#
# Please note that the PDB file used in this tutorial only contains the upper part of the **Heavy chains** (variable region). For a comprehensive example of a **complete antibody**, please refer to [5DK3 PDB](https://www.rcsb.org/structure/5DK3) (Pembrolizumab IgG4 antibody).
#
# ***
# **Building Blocks** used:
#  - [biobb_pdb_tidy](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_tidy) from **biobb_pdb_tools.pdb_tools.biobb_pdb_tidy**
#  - [biobb_pdb_selchain](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_selchain) from **biobb_pdb_tools.pdb_tools.biobb_pdb_selchain**
#  - [biobb_pdb_delhetatm](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_delhetatm) from **biobb_pdb_tools.pdb_tools.biobb_pdb_delhetatm**
#  - [biobb_pdb_fixinsert](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_fixinsert) from **biobb_pdb_tools.pdb_tools.biobb_pdb_fixinsert**
#  - [biobb_pdb_selaltloc](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_selaltloc) from **biobb_pdb_tools.pdb_tools.biobb_pdb_selaltloc**
#  - [biobb_pdb_keepcord](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_keepcord) from **biobb_pdb_tools.pdb_tools.biobb_pdb_keepcord**
#  - [biobb_pdb_selres](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_selres) from **biobb_pdb_tools.pdb_tools.biobb_pdb_selres**
#  - [biobb_pdb_reres](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_reres) from **biobb_pdb_tools.pdb_tools.biobb_pdb_reres**
#  - [biobb_pdb_merge](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_merge) from **biobb_pdb_tools.pdb_tools.biobb_pdb_merge**
#  - [biobb_pdb_chain](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_chain) from **biobb_pdb_tools.pdb_tools.biobb_pdb_chain**
#  - [biobb_pdb_chainxseg](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_chainxseg) from **biobb_pdb_tools.pdb_tools.biobb_pdb_chainxseg**
# ***
#
# #### Complete pdb_tools version from the official HADDOCK3 tutorial:
# `pdb_tidy -strict 4G6K.pdb | pdb_selchain -H | pdb_delhetatm | pdb_fixinsert | pdb_selaltloc | pdb_keepcoord | pdb_selres -1:120 | pdb_tidy -strict > 4G6K_H.pdb`

# %% [markdown]
# ### [Preparing the Antibody structure] Step 1: Select and extract protein regions/chains
# **Extract chains** (Heavy: H, Light; L) and select specific residues from the **Variable Fragment (Fv)**.<br>
# Two PDB files should be generated:
# - *4G6K_H_reduced.pdb* (Heavy, FV)
# - *4G6K_L_reduced.pdb* (Light, FV)

# %%
from biobb_pdb_tools.pdb_tools import  *

pdb_final = {}
for ch, sel in [('H',120),('L',107)]:
    
    # Create properties dict and inputs/outputs

    # CHAINS H (Heavy), L (Light)
    pdb_final[ch] = f'{out_path}/pre/{antibody_pdb}_{ch}_reduced.pdb'
    
    steps = [
        (biobb_pdb_tidy.biobb_pdb_tidy,           {'strict': True}),              # Adhere to the format specifications
        (biobb_pdb_selchain.biobb_pdb_selchain,   {'chains': ch}),                # Extract chain
        (biobb_pdb_delhetatm.biobb_pdb_delhetatm, {}),                            # Remove all HETATM records 
        (biobb_pdb_fixinsert.biobb_pdb_fixinsert, {}),                            # Delete insertion codes and shift residue numbering 
        (biobb_pdb_selaltloc.biobb_pdb_selaltloc, {}),                            # Select altloc labels (highest occupancy) 
        (biobb_pdb_keepcoord.biobb_pdb_keepcoord, {}),                            # Remove all non-coordinate records 
        (biobb_pdb_selres.biobb_pdb_selres,       {'selection': '1:'+str(sel)}),  # Select residues by their range
        (biobb_pdb_tidy.biobb_pdb_tidy,           {})                             # Adhere to the format specifications
    ]

    # Create and launch bb
    pdb_tools_pipeline(ab_pdb, pdb_final[ch], steps)
# Out:
# 2026-01-22 16:55:09,692 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_tidy Version: 5.2.0
# 2026-01-22 16:55:09,693 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_d0587b91-e596-4d0e-a1a8-2402bb712391
# 2026-01-22 16:55:09,695 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4G6K_0.pdb --> sandbox_d0587b91-e596-4d0e-a1a8-2402bb712391
# 2026-01-22 16:55:09,696 [MainThread  ] [INFO ]  Appending optional boolean property
# 2026-01-22 16:55:09,697 [MainThread  ] [INFO ]  pdb_tidy -strict ./data/antibody/pre/4G6K_0.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb
# 2026-01-22 16:55:09,697 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:09,698 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_tidy -strict ./data/antibody/pre/4G6K_0.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb
# 2026-01-22 16:55:09,767 [MainThread  ] [INFO ]  Command 'pdb_tidy -strict ./data/antibody/pre/4G6K_0.pdb > ./data/antibody/pre/4G6K_H_red...' finalized with exit code 0
# 2026-01-22 16:55:09,770 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_d0587b91-e596-4d0e-a1a8-2402bb712391']
# 2026-01-22 16:55:09,771 [MainThread  ] [INFO ]
# 2026-01-22 16:55:09,773 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_selchain Version: 5.2.0
# 2026-01-22 16:55:09,774 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_63fc414a-afab-4da1-bed1-d22933169b12
# 2026-01-22 16:55:09,775 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_63fc414a-afab-4da1-bed1-d22933169b12
# 2026-01-22 16:55:09,776 [MainThread  ] [INFO ]  Appending chains to select
# 2026-01-22 16:55:09,776 [MainThread  ] [INFO ]  pdb_selchain -H /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_63fc414a-afab-4da1-bed1-d22933169b12/tmp.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb
# 2026-01-22 16:55:09,777 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:09,777 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_selchain -H /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_63fc414a-afab-4da1-bed1-d22933169b12/tmp.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb
# 2026-01-22 16:55:09,828 [MainThread  ] [INFO ]  Command 'pdb_selchain -H /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_...' finalized with exit code 0
# 2026-01-22 16:55:09,831 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_63fc414a-afab-4da1-bed1-d22933169b12']
# 2026-01-22 16:55:09,832 [MainThread  ] [INFO ]
# 2026-01-22 16:55:09,834 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_delhetatm Version: 5.2.0
# 2026-01-22 16:55:09,835 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b37f2696-2aae-4bdc-ae92-c4238f24ef03
# 2026-01-22 16:55:09,836 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_b37f2696-2aae-4bdc-ae92-c4238f24ef03
# 2026-01-22 16:55:09,838 [MainThread  ] [INFO ]  pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b37f2696-2aae-4bdc-ae92-c4238f24ef03/tmp.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb
# 2026-01-22 16:55:09,838 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:09,839 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b37f2696-2aae-4bdc-ae92-c4238f24ef03/tmp.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb
# 2026-01-22 16:55:09,890 [MainThread  ] [INFO ]  Command 'pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf...' finalized with exit code 0
# 2026-01-22 16:55:09,893 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b37f2696-2aae-4bdc-ae92-c4238f24ef03']
# 2026-01-22 16:55:09,893 [MainThread  ] [INFO ]
# 2026-01-22 16:55:09,896 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_fixinsert Version: 5.2.0
# 2026-01-22 16:55:09,897 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b1ec58c1-94cb-4d21-b224-f163337c3ca4
# 2026-01-22 16:55:09,898 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_b1ec58c1-94cb-4d21-b224-f163337c3ca4
# 2026-01-22 16:55:09,899 [MainThread  ] [INFO ]  pdb_fixinsert  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b1ec58c1-94cb-4d21-b224-f163337c3ca4/tmp.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb
# 2026-01-22 16:55:09,899 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:09,900 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_fixinsert  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b1ec58c1-94cb-4d21-b224-f163337c3ca4/tmp.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb
# 2026-01-22 16:55:09,952 [MainThread  ] [INFO ]  Command 'pdb_fixinsert  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_w...' finalized with exit code 0
# 2026-01-22 16:55:09,954 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b1ec58c1-94cb-4d21-b224-f163337c3ca4']
# 2026-01-22 16:55:09,955 [MainThread  ] [INFO ]
# 2026-01-22 16:55:09,958 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_selaltloc Version: 5.2.0
# 2026-01-22 16:55:09,958 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_41bce940-74b4-4f30-984c-4d643a381adb
# 2026-01-22 16:55:09,960 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_41bce940-74b4-4f30-984c-4d643a381adb
# 2026-01-22 16:55:09,961 [MainThread  ] [INFO ]  pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_41bce940-74b4-4f30-984c-4d643a381adb/tmp.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb
# 2026-01-22 16:55:09,961 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:09,962 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_41bce940-74b4-4f30-984c-4d643a381adb/tmp.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb
# 2026-01-22 16:55:10,021 [MainThread  ] [INFO ]  Command 'pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_w...' finalized with exit code 0
# 2026-01-22 16:55:10,024 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_41bce940-74b4-4f30-984c-4d643a381adb']
# 2026-01-22 16:55:10,025 [MainThread  ] [INFO ]
# 2026-01-22 16:55:10,027 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_keepcoord Version: 5.2.0
# 2026-01-22 16:55:10,028 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_9b533fdd-fa60-4d41-b42b-1e7887300cbd
# 2026-01-22 16:55:10,028 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_9b533fdd-fa60-4d41-b42b-1e7887300cbd
# 2026-01-22 16:55:10,029 [MainThread  ] [INFO ]  pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_9b533fdd-fa60-4d41-b42b-1e7887300cbd/tmp.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb
# 2026-01-22 16:55:10,030 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:10,030 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_9b533fdd-fa60-4d41-b42b-1e7887300cbd/tmp.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb
# 2026-01-22 16:55:10,081 [MainThread  ] [INFO ]  Command 'pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf...' finalized with exit code 0
# 2026-01-22 16:55:10,083 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_9b533fdd-fa60-4d41-b42b-1e7887300cbd']
# 2026-01-22 16:55:10,084 [MainThread  ] [INFO ]
# 2026-01-22 16:55:10,086 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_selres Version: 5.2.0
# 2026-01-22 16:55:10,087 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_08f5cf87-8e33-4c71-a5de-a2058943899f
# 2026-01-22 16:55:10,087 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_08f5cf87-8e33-4c71-a5de-a2058943899f
# 2026-01-22 16:55:10,088 [MainThread  ] [INFO ]  Selecting residues with pattern: 1:120
# 2026-01-22 16:55:10,089 [MainThread  ] [INFO ]  pdb_selres -1:120 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_08f5cf87-8e33-4c71-a5de-a2058943899f/tmp.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb
# 2026-01-22 16:55:10,089 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:10,090 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_selres -1:120 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_08f5cf87-8e33-4c71-a5de-a2058943899f/tmp.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb
# 2026-01-22 16:55:10,155 [MainThread  ] [INFO ]  Command 'pdb_selres -1:120 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biob...' finalized with exit code 0
# 2026-01-22 16:55:10,159 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_08f5cf87-8e33-4c71-a5de-a2058943899f']
# 2026-01-22 16:55:10,159 [MainThread  ] [INFO ]
# 2026-01-22 16:55:10,162 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_tidy Version: 5.2.0
# 2026-01-22 16:55:10,163 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_e34f7928-521c-452f-8cb0-4d020c9b10df
# 2026-01-22 16:55:10,164 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_e34f7928-521c-452f-8cb0-4d020c9b10df
# 2026-01-22 16:55:10,165 [MainThread  ] [INFO ]  pdb_tidy  tmp.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb
# 2026-01-22 16:55:10,166 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:10,166 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_tidy  tmp.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb
# 2026-01-22 16:55:10,217 [MainThread  ] [INFO ]  Command 'pdb_tidy  tmp.pdb > ./data/antibody/pre/4G6K_H_reduced.pdb...' finalized with exit code 0
# 2026-01-22 16:55:10,219 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_e34f7928-521c-452f-8cb0-4d020c9b10df']
# 2026-01-22 16:55:10,220 [MainThread  ] [INFO ]
# 2026-01-22 16:55:10,222 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_tidy Version: 5.2.0
# 2026-01-22 16:55:10,223 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_597efbba-2759-419a-8cdb-a39c86adfbf3
# 2026-01-22 16:55:10,224 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4G6K_0.pdb --> sandbox_597efbba-2759-419a-8cdb-a39c86adfbf3
# 2026-01-22 16:55:10,225 [MainThread  ] [INFO ]  Appending optional boolean property
# 2026-01-22 16:55:10,225 [MainThread  ] [INFO ]  pdb_tidy -strict ./data/antibody/pre/4G6K_0.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb
# 2026-01-22 16:55:10,225 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:10,226 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_tidy -strict ./data/antibody/pre/4G6K_0.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb
# 2026-01-22 16:55:10,282 [MainThread  ] [INFO ]  Command 'pdb_tidy -strict ./data/antibody/pre/4G6K_0.pdb > ./data/antibody/pre/4G6K_L_red...' finalized with exit code 0
# 2026-01-22 16:55:10,285 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_597efbba-2759-419a-8cdb-a39c86adfbf3']
# 2026-01-22 16:55:10,285 [MainThread  ] [INFO ]
# 2026-01-22 16:55:10,288 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_selchain Version: 5.2.0
# 2026-01-22 16:55:10,288 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_32d3f16e-c886-4dfe-b843-0d67a5464f58
# 2026-01-22 16:55:10,289 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_32d3f16e-c886-4dfe-b843-0d67a5464f58
# 2026-01-22 16:55:10,291 [MainThread  ] [INFO ]  Appending chains to select
# 2026-01-22 16:55:10,291 [MainThread  ] [INFO ]  pdb_selchain -L /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_32d3f16e-c886-4dfe-b843-0d67a5464f58/tmp.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb
# 2026-01-22 16:55:10,292 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:10,292 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_selchain -L /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_32d3f16e-c886-4dfe-b843-0d67a5464f58/tmp.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb
# 2026-01-22 16:55:10,343 [MainThread  ] [INFO ]  Command 'pdb_selchain -L /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_...' finalized with exit code 0
# 2026-01-22 16:55:10,346 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_32d3f16e-c886-4dfe-b843-0d67a5464f58']
# 2026-01-22 16:55:10,347 [MainThread  ] [INFO ]
# 2026-01-22 16:55:10,350 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_delhetatm Version: 5.2.0
# 2026-01-22 16:55:10,350 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_ce6c5d3a-f723-4007-a4b2-9603106fca05
# 2026-01-22 16:55:10,351 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_ce6c5d3a-f723-4007-a4b2-9603106fca05
# 2026-01-22 16:55:10,353 [MainThread  ] [INFO ]  pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_ce6c5d3a-f723-4007-a4b2-9603106fca05/tmp.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb
# 2026-01-22 16:55:10,353 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:10,354 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_ce6c5d3a-f723-4007-a4b2-9603106fca05/tmp.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb
# 2026-01-22 16:55:10,404 [MainThread  ] [INFO ]  Command 'pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf...' finalized with exit code 0
# 2026-01-22 16:55:10,407 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_ce6c5d3a-f723-4007-a4b2-9603106fca05']
# 2026-01-22 16:55:10,408 [MainThread  ] [INFO ]
# 2026-01-22 16:55:10,410 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_fixinsert Version: 5.2.0
# 2026-01-22 16:55:10,411 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_1840e771-647a-4b6b-b4dc-f73667bbd38f
# 2026-01-22 16:55:10,412 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_1840e771-647a-4b6b-b4dc-f73667bbd38f
# 2026-01-22 16:55:10,413 [MainThread  ] [INFO ]  pdb_fixinsert  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_1840e771-647a-4b6b-b4dc-f73667bbd38f/tmp.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb
# 2026-01-22 16:55:10,414 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:10,415 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_fixinsert  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_1840e771-647a-4b6b-b4dc-f73667bbd38f/tmp.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb
# 2026-01-22 16:55:10,468 [MainThread  ] [INFO ]  Command 'pdb_fixinsert  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_w...' finalized with exit code 0
# 2026-01-22 16:55:10,471 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_1840e771-647a-4b6b-b4dc-f73667bbd38f']
# 2026-01-22 16:55:10,471 [MainThread  ] [INFO ]
# 2026-01-22 16:55:10,474 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_selaltloc Version: 5.2.0
# 2026-01-22 16:55:10,475 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_4d0083aa-ed7a-41ae-80ed-b3cfbd3cf974
# 2026-01-22 16:55:10,476 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_4d0083aa-ed7a-41ae-80ed-b3cfbd3cf974
# 2026-01-22 16:55:10,477 [MainThread  ] [INFO ]  pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_4d0083aa-ed7a-41ae-80ed-b3cfbd3cf974/tmp.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb
# 2026-01-22 16:55:10,477 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:10,478 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_4d0083aa-ed7a-41ae-80ed-b3cfbd3cf974/tmp.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb
# 2026-01-22 16:55:10,537 [MainThread  ] [INFO ]  Command 'pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_w...' finalized with exit code 0
# 2026-01-22 16:55:10,540 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_4d0083aa-ed7a-41ae-80ed-b3cfbd3cf974']
# 2026-01-22 16:55:10,540 [MainThread  ] [INFO ]
# 2026-01-22 16:55:10,543 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_keepcoord Version: 5.2.0
# 2026-01-22 16:55:10,543 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_eba9465d-5c7e-4c78-a874-9dbc0e049f12
# 2026-01-22 16:55:10,544 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_eba9465d-5c7e-4c78-a874-9dbc0e049f12
# 2026-01-22 16:55:10,545 [MainThread  ] [INFO ]  pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_eba9465d-5c7e-4c78-a874-9dbc0e049f12/tmp.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb
# 2026-01-22 16:55:10,545 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:10,546 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_eba9465d-5c7e-4c78-a874-9dbc0e049f12/tmp.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb
# 2026-01-22 16:55:10,598 [MainThread  ] [INFO ]  Command 'pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf...' finalized with exit code 0
# 2026-01-22 16:55:10,600 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_eba9465d-5c7e-4c78-a874-9dbc0e049f12']
# 2026-01-22 16:55:10,601 [MainThread  ] [INFO ]
# 2026-01-22 16:55:10,603 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_selres Version: 5.2.0
# 2026-01-22 16:55:10,604 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_2f30e00a-c0a0-4495-8d51-45ea70011ead
# 2026-01-22 16:55:10,604 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_2f30e00a-c0a0-4495-8d51-45ea70011ead
# 2026-01-22 16:55:10,605 [MainThread  ] [INFO ]  Selecting residues with pattern: 1:107
# 2026-01-22 16:55:10,605 [MainThread  ] [INFO ]  pdb_selres -1:107 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_2f30e00a-c0a0-4495-8d51-45ea70011ead/tmp.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb
# 2026-01-22 16:55:10,606 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:10,606 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_selres -1:107 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_2f30e00a-c0a0-4495-8d51-45ea70011ead/tmp.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb
# 2026-01-22 16:55:10,669 [MainThread  ] [INFO ]  Command 'pdb_selres -1:107 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biob...' finalized with exit code 0
# 2026-01-22 16:55:10,672 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_2f30e00a-c0a0-4495-8d51-45ea70011ead']
# 2026-01-22 16:55:10,672 [MainThread  ] [INFO ]
# 2026-01-22 16:55:10,675 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_tidy Version: 5.2.0
# 2026-01-22 16:55:10,675 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_36e98f87-3189-43f0-b885-409eb6bd64bd
# 2026-01-22 16:55:10,676 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_36e98f87-3189-43f0-b885-409eb6bd64bd
# 2026-01-22 16:55:10,677 [MainThread  ] [INFO ]  pdb_tidy  tmp.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb
# 2026-01-22 16:55:10,677 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:10,678 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_tidy  tmp.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb
# 2026-01-22 16:55:10,730 [MainThread  ] [INFO ]  Command 'pdb_tidy  tmp.pdb > ./data/antibody/pre/4G6K_L_reduced.pdb...' finalized with exit code 0
# 2026-01-22 16:55:10,732 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_36e98f87-3189-43f0-b885-409eb6bd64bd']
# 2026-01-22 16:55:10,733 [MainThread  ] [INFO ]

# %% [markdown]
# ### [Preparing the Antibody structure] Step 2: Merge regions into a single file
# Merge **both chains** (Heavy, Light) into a single PDB file. <br>
# - *4G6K_clean.pdb* (Heavy + Light chains, FV)

# %%
from biobb_pdb_tools.pdb_tools.biobb_pdb_merge import biobb_pdb_merge

# Join the generated PDB files in a single ZIP file 
zip_file_path = f'{out_path}/pre/{antibody_pdb}_HL.zip'
# Create a zip file and add the pdb_out file to it
with zipfile.ZipFile(zip_file_path, 'w') as zipf:
    zipf.write(pdb_final['H'], arcname=f'{antibody_pdb}_H.pdb')
    zipf.write(pdb_final['L'], arcname=f'{antibody_pdb}_L.pdb')
    
# Create properties dict and inputs/outputs
complexFile = f'{out_path}/pre/{antibody_pdb}_clean_merge.pdb' 

# Create and launch bb
biobb_pdb_merge(input_file_path = zip_file_path,  
                output_file_path=complexFile)
# Out:
# 2026-01-22 16:55:13,045 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_merge Version: 5.2.0
# 2026-01-22 16:55:13,047 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_90e46c92-784f-4540-a5ca-3a8d374db7c4
# 2026-01-22 16:55:13,048 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4G6K_HL.zip --> sandbox_90e46c92-784f-4540-a5ca-3a8d374db7c4
# 2026-01-22 16:55:13,053 [MainThread  ] [INFO ]  pdb_merge /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_90e46c92-784f-4540-a5ca-3a8d374db7c4/4G6K_H.pdb /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_90e46c92-784f-4540-a5ca-3a8d374db7c4/4G6K_L.pdb > ./data/antibody/pre/4G6K_clean_merge.pdb
# 2026-01-22 16:55:13,054 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:13,056 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_merge /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_90e46c92-784f-4540-a5ca-3a8d374db7c4/4G6K_H.pdb /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_90e46c92-784f-4540-a5ca-3a8d374db7c4/4G6K_L.pdb > ./data/antibody/pre/4G6K_clean_merge.pdb
# 2026-01-22 16:55:13,138 [MainThread  ] [INFO ]  Command 'pdb_merge /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_had...' finalized with exit code 0
# 2026-01-22 16:55:13,141 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_90e46c92-784f-4540-a5ca-3a8d374db7c4']
# 2026-01-22 16:55:13,142 [MainThread  ] [INFO ]
# 0

# %% [markdown]
# ### [Preparing the Antibody structure] Step 3: Prepare PDB file to meet HADDOCK3 requirements
# Add **single chain id** to the whole structure, **renumber residue ids**, and add chain id in the **segment identifier**.<br>
# - *4G6K_clean_seg.pdb*

# %%
# Create properties dict and inputs/outputs
antibody_prep = f'{out_path}/pre/{antibody_pdb}_clean.pdb'

steps = [
    (biobb_pdb_reres.biobb_pdb_reres,         {'number': 1}),      # Renumber the residues starting from 1
    (biobb_pdb_chain.biobb_pdb_chain,         {'chain': 'A'}),     # Modify the chain identifier column 
    (biobb_pdb_chainxseg.biobb_pdb_chainxseg, {}),                 # Swap the segment identifier for the chain identifier
    (biobb_pdb_tidy.biobb_pdb_tidy,           {'strict': True}),   # Adhere to the format specifications
]

# Create and launch bb
pdb_tools_pipeline(complexFile, antibody_prep, steps)
# Out:
# 2026-01-22 16:55:14,971 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_reres Version: 5.2.0
# 2026-01-22 16:55:14,972 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_6904820d-20b4-49eb-a34e-e6d156e782ae
# 2026-01-22 16:55:14,973 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4G6K_clean_merge.pdb --> sandbox_6904820d-20b4-49eb-a34e-e6d156e782ae
# 2026-01-22 16:55:14,975 [MainThread  ] [INFO ]  Appending optional boolean property
# 2026-01-22 16:55:14,976 [MainThread  ] [INFO ]  pdb_reres -1 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_6904820d-20b4-49eb-a34e-e6d156e782ae/4G6K_clean_merge.pdb > ./data/antibody/pre/4G6K_clean.pdb
# 2026-01-22 16:55:14,976 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:14,977 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_reres -1 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_6904820d-20b4-49eb-a34e-e6d156e782ae/4G6K_clean_merge.pdb > ./data/antibody/pre/4G6K_clean.pdb
# 2026-01-22 16:55:15,046 [MainThread  ] [INFO ]  Command 'pdb_reres -1 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_...' finalized with exit code 0
# 2026-01-22 16:55:15,049 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_6904820d-20b4-49eb-a34e-e6d156e782ae']
# 2026-01-22 16:55:15,050 [MainThread  ] [INFO ]
# 2026-01-22 16:55:15,053 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_chain Version: 5.2.0
# 2026-01-22 16:55:15,053 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_09a8bfaa-5524-4b50-9506-d03ac9b55541
# 2026-01-22 16:55:15,054 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_09a8bfaa-5524-4b50-9506-d03ac9b55541
# 2026-01-22 16:55:15,055 [MainThread  ] [INFO ]  Appending optional boolean property
# 2026-01-22 16:55:15,056 [MainThread  ] [INFO ]  pdb_chain -A /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_09a8bfaa-5524-4b50-9506-d03ac9b55541/tmp.pdb > ./data/antibody/pre/4G6K_clean.pdb
# 2026-01-22 16:55:15,056 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:15,057 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_chain -A /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_09a8bfaa-5524-4b50-9506-d03ac9b55541/tmp.pdb > ./data/antibody/pre/4G6K_clean.pdb
# 2026-01-22 16:55:15,109 [MainThread  ] [INFO ]  Command 'pdb_chain -A /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_...' finalized with exit code 0
# 2026-01-22 16:55:15,112 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_09a8bfaa-5524-4b50-9506-d03ac9b55541']
# 2026-01-22 16:55:15,112 [MainThread  ] [INFO ]
# 2026-01-22 16:55:15,115 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_chainxseg Version: 5.2.0
# 2026-01-22 16:55:15,116 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f5a0fa7a-0156-4ef1-8727-a0decd9b4580
# 2026-01-22 16:55:15,116 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_f5a0fa7a-0156-4ef1-8727-a0decd9b4580
# 2026-01-22 16:55:15,117 [MainThread  ] [INFO ]  pdb_chainxseg /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f5a0fa7a-0156-4ef1-8727-a0decd9b4580/tmp.pdb > ./data/antibody/pre/4G6K_clean.pdb
# 2026-01-22 16:55:15,118 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:15,118 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_chainxseg /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f5a0fa7a-0156-4ef1-8727-a0decd9b4580/tmp.pdb > ./data/antibody/pre/4G6K_clean.pdb
# 2026-01-22 16:55:15,167 [MainThread  ] [INFO ]  Command 'pdb_chainxseg /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf...' finalized with exit code 0
# 2026-01-22 16:55:15,169 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f5a0fa7a-0156-4ef1-8727-a0decd9b4580']
# 2026-01-22 16:55:15,170 [MainThread  ] [INFO ]
# 2026-01-22 16:55:15,172 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_tidy Version: 5.2.0
# 2026-01-22 16:55:15,173 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_ffe83893-293e-4627-bf6f-5b67f3f6cf9d
# 2026-01-22 16:55:15,174 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_ffe83893-293e-4627-bf6f-5b67f3f6cf9d
# 2026-01-22 16:55:15,174 [MainThread  ] [INFO ]  Appending optional boolean property
# 2026-01-22 16:55:15,175 [MainThread  ] [INFO ]  pdb_tidy -strict tmp.pdb > ./data/antibody/pre/4G6K_clean.pdb
# 2026-01-22 16:55:15,175 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:15,176 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_tidy -strict tmp.pdb > ./data/antibody/pre/4G6K_clean.pdb
# 2026-01-22 16:55:15,226 [MainThread  ] [INFO ]  Command 'pdb_tidy -strict tmp.pdb > ./data/antibody/pre/4G6K_clean.pdb...' finalized with exit code 0
# 2026-01-22 16:55:15,229 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_ffe83893-293e-4627-bf6f-5b67f3f6cf9d']
# 2026-01-22 16:55:15,230 [MainThread  ] [INFO ]

# %% [markdown]
# ### [Preparing the Antibody structure] Step 4: Visualize final structure (antibody)
#
# - Left: **Original antibody**, for comparison. Heavy Chain: Blue; Light Chain: Red.
# - Right: **Prepared structure**, with only the variable domain (FV). Heavy Chain: Blue; Light Chain: Red.

# %%
# Show structures: Fv with and without contant domain
view1 = nv.show_structure_file(ab_pdb)
view1._remote_call('setSize', target='Widget', args=['500px','400px'])
view1.clear_representations()
view1.add_representation(repr_type='cartoon', selection=':H', color='blue')
view1.add_representation(repr_type='cartoon', selection=':L', color='red')
view1.add_representation(repr_type='surface', radius='.3', selection='1-120:H', color='blue')
view1.add_representation(repr_type='surface', radius='.3', selection='1-107:L', color='red')
view1.camera='orthographic'
view1
view2 = nv.show_structure_file(antibody_prep)
view2._remote_call('setSize', target='Widget', args=['500px','400px'])
view2.clear_representations()
view2.add_representation(repr_type='surface', radius='.3', selection='1-120:A', color='blue')
view2.add_representation(repr_type='surface', radius='.3', selection='121-228:A', color='red')
view2.camera='orthographic'
view2
ipywidgets.HBox([view1, view2])
# Out:
# HBox(children=(NGLWidget(), NGLWidget()))

# %% [markdown]
# ## Preparing the antigen structure
#
# The **Interleukin-1β (IL-1β) antigen** also needs to be processed to meet **HADDOCK3 requirements**. In particular, as each molecule given to **HADDOCK3** in a docking scenario must have a **unique chain id / segment id**, a new identifier ***-B-*** will be assigned.
#
# ***
# **Building Blocks** used:
#  - [biobb_pdb_tidy](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_tidy) from **biobb_pdb_tools.pdb_tools.biobb_pdb_tidy**
#  - [biobb_pdb_delhetatm](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_delhetatm) from **biobb_pdb_tools.pdb_tools.biobb_pdb_delhetatm**
#  - [biobb_pdb_selaltloc](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_selaltloc) from **biobb_pdb_tools.pdb_tools.biobb_pdb_selaltloc**
#  - [biobb_pdb_keepcord](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_keepcord) from **biobb_pdb_tools.pdb_tools.biobb_pdb_keepcord**
#  - [biobb_pdb_chain](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_chain) from **biobb_pdb_tools.pdb_tools.biobb_pdb_chain**
#  - [biobb_pdb_chainxseg](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_chainxseg) from **biobb_pdb_tools.pdb_tools.biobb_pdb_chainxseg**
#
# ***
#
# #### Complete pdb_tools version from the official HADDOCK3 tutorial:
#
# `pdb_fetch 4I1B | pdb_tidy -strict | pdb_delhetatm | pdb_selaltloc | pdb_keepcoord | pdb_chain -B | pdb_chainxseg | pdb_tidy -strict > 4I1B_clean.pdb`

# %%
# Create properties dict and inputs/outputs
antigen_prep = f'{out_path}/pre/{antigen_pdb}_clean.pdb'

# Create and launch bb
steps = [
    (biobb_pdb_tidy.biobb_pdb_tidy,           {'strict': True}),   # Adhere to the format specifications
    (biobb_pdb_delhetatm.biobb_pdb_delhetatm, {}),                 # Remove all HETATM records 
    (biobb_pdb_selaltloc.biobb_pdb_selaltloc, {}),                 # Select altloc labels (highest occupancy) 
    (biobb_pdb_keepcoord.biobb_pdb_keepcoord, {}),                 # Remove all non-coordinate records 
    (biobb_pdb_chain.biobb_pdb_chain,         {'chain': 'B'}),     # Modify the chain identifier column 
    (biobb_pdb_chainxseg.biobb_pdb_chainxseg, {}),                 # Swap the segment identifier for the chain identifier
    (biobb_pdb_tidy.biobb_pdb_tidy,           {'strict': True})    # Adhere to the format specifications
]
pdb_tools_pipeline(ag_pdb, antigen_prep, steps)
# Out:
# 2026-01-22 16:55:19,576 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_tidy Version: 5.2.0
# 2026-01-22 16:55:19,578 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_d0f18f16-94ba-4f59-a262-135d767a7b27
# 2026-01-22 16:55:19,579 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4I1B_0.pdb --> sandbox_d0f18f16-94ba-4f59-a262-135d767a7b27
# 2026-01-22 16:55:19,582 [MainThread  ] [INFO ]  Appending optional boolean property
# 2026-01-22 16:55:19,582 [MainThread  ] [INFO ]  pdb_tidy -strict ./data/antibody/pre/4I1B_0.pdb > ./data/antibody/pre/4I1B_clean.pdb
# 2026-01-22 16:55:19,583 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:19,584 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_tidy -strict ./data/antibody/pre/4I1B_0.pdb > ./data/antibody/pre/4I1B_clean.pdb
# 2026-01-22 16:55:19,653 [MainThread  ] [INFO ]  Command 'pdb_tidy -strict ./data/antibody/pre/4I1B_0.pdb > ./data/antibody/pre/4I1B_clean...' finalized with exit code 0
# 2026-01-22 16:55:19,655 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_d0f18f16-94ba-4f59-a262-135d767a7b27']
# 2026-01-22 16:55:19,656 [MainThread  ] [INFO ]
# 2026-01-22 16:55:19,659 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_delhetatm Version: 5.2.0
# 2026-01-22 16:55:19,660 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b1c8b435-6f9a-44da-8896-bed1cda3eb98
# 2026-01-22 16:55:19,661 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_b1c8b435-6f9a-44da-8896-bed1cda3eb98
# 2026-01-22 16:55:19,663 [MainThread  ] [INFO ]  pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b1c8b435-6f9a-44da-8896-bed1cda3eb98/tmp.pdb > ./data/antibody/pre/4I1B_clean.pdb
# 2026-01-22 16:55:19,663 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:19,664 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b1c8b435-6f9a-44da-8896-bed1cda3eb98/tmp.pdb > ./data/antibody/pre/4I1B_clean.pdb
# 2026-01-22 16:55:19,714 [MainThread  ] [INFO ]  Command 'pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf...' finalized with exit code 0
# 2026-01-22 16:55:19,717 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b1c8b435-6f9a-44da-8896-bed1cda3eb98']
# 2026-01-22 16:55:19,718 [MainThread  ] [INFO ]
# 2026-01-22 16:55:19,720 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_selaltloc Version: 5.2.0
# 2026-01-22 16:55:19,721 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f5cf8781-eee6-45e7-a538-41f5142a3719
# 2026-01-22 16:55:19,722 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_f5cf8781-eee6-45e7-a538-41f5142a3719
# 2026-01-22 16:55:19,723 [MainThread  ] [INFO ]  pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f5cf8781-eee6-45e7-a538-41f5142a3719/tmp.pdb > ./data/antibody/pre/4I1B_clean.pdb
# 2026-01-22 16:55:19,723 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:19,724 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f5cf8781-eee6-45e7-a538-41f5142a3719/tmp.pdb > ./data/antibody/pre/4I1B_clean.pdb
# 2026-01-22 16:55:19,779 [MainThread  ] [INFO ]  Command 'pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_w...' finalized with exit code 0
# 2026-01-22 16:55:19,782 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f5cf8781-eee6-45e7-a538-41f5142a3719']
# 2026-01-22 16:55:19,782 [MainThread  ] [INFO ]
# 2026-01-22 16:55:19,786 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_keepcoord Version: 5.2.0
# 2026-01-22 16:55:19,787 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b9ce5ebc-b891-45d9-9095-23c34ca1446b
# 2026-01-22 16:55:19,787 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_b9ce5ebc-b891-45d9-9095-23c34ca1446b
# 2026-01-22 16:55:19,789 [MainThread  ] [INFO ]  pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b9ce5ebc-b891-45d9-9095-23c34ca1446b/tmp.pdb > ./data/antibody/pre/4I1B_clean.pdb
# 2026-01-22 16:55:19,789 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:19,790 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b9ce5ebc-b891-45d9-9095-23c34ca1446b/tmp.pdb > ./data/antibody/pre/4I1B_clean.pdb
# 2026-01-22 16:55:19,839 [MainThread  ] [INFO ]  Command 'pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf...' finalized with exit code 0
# 2026-01-22 16:55:19,842 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b9ce5ebc-b891-45d9-9095-23c34ca1446b']
# 2026-01-22 16:55:19,843 [MainThread  ] [INFO ]
# 2026-01-22 16:55:19,845 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_chain Version: 5.2.0
# 2026-01-22 16:55:19,846 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_c94466f2-c8f5-4b8c-ab4f-37eb4a7486dd
# 2026-01-22 16:55:19,846 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_c94466f2-c8f5-4b8c-ab4f-37eb4a7486dd
# 2026-01-22 16:55:19,848 [MainThread  ] [INFO ]  Appending optional boolean property
# 2026-01-22 16:55:19,848 [MainThread  ] [INFO ]  pdb_chain -B /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_c94466f2-c8f5-4b8c-ab4f-37eb4a7486dd/tmp.pdb > ./data/antibody/pre/4I1B_clean.pdb
# 2026-01-22 16:55:19,848 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:19,849 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_chain -B /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_c94466f2-c8f5-4b8c-ab4f-37eb4a7486dd/tmp.pdb > ./data/antibody/pre/4I1B_clean.pdb
# 2026-01-22 16:55:19,895 [MainThread  ] [INFO ]  Command 'pdb_chain -B /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_...' finalized with exit code 0
# 2026-01-22 16:55:19,898 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_c94466f2-c8f5-4b8c-ab4f-37eb4a7486dd']
# 2026-01-22 16:55:19,898 [MainThread  ] [INFO ]
# 2026-01-22 16:55:19,900 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_chainxseg Version: 5.2.0
# 2026-01-22 16:55:19,901 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_fb440b71-62cd-40a3-a208-c33b8c7aa59e
# 2026-01-22 16:55:19,902 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_fb440b71-62cd-40a3-a208-c33b8c7aa59e
# 2026-01-22 16:55:19,903 [MainThread  ] [INFO ]  pdb_chainxseg /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_fb440b71-62cd-40a3-a208-c33b8c7aa59e/tmp.pdb > ./data/antibody/pre/4I1B_clean.pdb
# 2026-01-22 16:55:19,903 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:19,904 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_chainxseg /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_fb440b71-62cd-40a3-a208-c33b8c7aa59e/tmp.pdb > ./data/antibody/pre/4I1B_clean.pdb
# 2026-01-22 16:55:19,951 [MainThread  ] [INFO ]  Command 'pdb_chainxseg /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf...' finalized with exit code 0
# 2026-01-22 16:55:19,953 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_fb440b71-62cd-40a3-a208-c33b8c7aa59e']
# 2026-01-22 16:55:19,954 [MainThread  ] [INFO ]
# 2026-01-22 16:55:19,956 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_tidy Version: 5.2.0
# 2026-01-22 16:55:19,956 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b5eeadfe-95f3-41ff-9695-9922f449f101
# 2026-01-22 16:55:19,957 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_b5eeadfe-95f3-41ff-9695-9922f449f101
# 2026-01-22 16:55:19,958 [MainThread  ] [INFO ]  Appending optional boolean property
# 2026-01-22 16:55:19,958 [MainThread  ] [INFO ]  pdb_tidy -strict tmp.pdb > ./data/antibody/pre/4I1B_clean.pdb
# 2026-01-22 16:55:19,960 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:19,960 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_tidy -strict tmp.pdb > ./data/antibody/pre/4I1B_clean.pdb
# 2026-01-22 16:55:20,009 [MainThread  ] [INFO ]  Command 'pdb_tidy -strict tmp.pdb > ./data/antibody/pre/4I1B_clean.pdb...' finalized with exit code 0
# 2026-01-22 16:55:20,011 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b5eeadfe-95f3-41ff-9695-9922f449f101']
# 2026-01-22 16:55:20,012 [MainThread  ] [INFO ]

# %% [markdown]
# ### Visualize final structure (antigen)
#
# - Left: **Original antigen**, for comparison.
# - Right: **Prepared structure**.
#
# Note that the only difference in this case is the **chain / segment ids** (changed from ***-A-*** to ***-B-***).

# %%
view1 = nv.show_structure_file(ag_pdb)
view1._remote_call('setSize', target='Widget', args=['500px','400px'])
view1.clear_representations()
view1.add_representation(repr_type='cartoon', selection=':A', color='green')
view1.camera='orthographic'
view2 = nv.show_structure_file(antigen_prep)
view2._remote_call('setSize', target='Widget', args=['500px','400px'])
view2.clear_representations()
view2.add_representation(repr_type='cartoon', selection=':B', color='green')
view2.camera='orthographic'
print('Click on the proteins to see the changed chain name')
ipywidgets.HBox([view1, view2])
# Out:
# Click on the proteins to see the changed chain name
# HBox(children=(NGLWidget(), NGLWidget()))

# %% [markdown]
# ## Preparing the reference structure
#
# Finally, since an experimentally solved structure of the **Antibody-Antigen** complex is available, we aim to compare the **intermediate results** of **HADDOCK3** with it. For this, the **reference PDB** should also be prepared.
#
# ***
# **Building Blocks** used:
#  - [biobb_pdb_selchain](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_selchain) from **biobb_pdb_tools.pdb_tools.biobb_pdb_selchain**
#  - [biobb_pdb_selres](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_selres) from **biobb_pdb_tools.pdb_tools.biobb_pdb_selres**
#  - [biobb_pdb_reres](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_reres) from **biobb_pdb_tools.pdb_tools.biobb_pdb_reres**
#  - [biobb_pdb_merge](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_merge) from **biobb_pdb_tools.pdb_tools.biobb_pdb_merge**
#  - [biobb_pdb_chain](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_chain) from **biobb_pdb_tools.pdb_tools.biobb_pdb_chain**
#  - [biobb_pdb_chainxseg](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_chainxseg) from **biobb_pdb_tools.pdb_tools.biobb_pdb_chainxseg**
#  - [biobb_pdb_tidy](https://biobb-pdb-tools.readthedocs.io/en/latest/pdb_tools.html#module-pdb_tools.biobb_pdb_tidy) from **biobb_pdb_tools.pdb_tools.biobb_pdb_tidy**
# ***

# %% [markdown]
# ### [Preparing the Reference structure] Step 1: Select and extract Heavy and Light antibody regions/chains from the complex
# **Extract chains** (Heavy: H, Light; L) and select specific residues from the **Variable Domain (FV)**.<br>
# Two PDB files should be generated:
# - *4G6M_H_reduced.pdb* (Heavy, FV)
# - *4G6M_L_reduced.pdb* (Light, FV)

# %%
# Create properties dict and inputs/outputs
pdb_ref = {}
pdb_in  = f'{out_path}/pre/{complex_pdb}_0.pdb'

for ch, sel in [('H',120),('L',107)]:
    pdb_ref[ch] = f'{out_path}/pre/{complex_pdb}_{ch}_reduced.pdb'
    steps = [
        (biobb_pdb_selchain.biobb_pdb_selchain,   {'chains': ch}),                # Extract chains
        (biobb_pdb_delhetatm.biobb_pdb_delhetatm, {}),                            # Remove all HETATM records
        (biobb_pdb_fixinsert.biobb_pdb_fixinsert, {}),                            # Delete insertion codes and shift residue numbering
        (biobb_pdb_selaltloc.biobb_pdb_selaltloc, {}),                            # Select altloc labels (highest occupancy) 
        (biobb_pdb_keepcoord.biobb_pdb_keepcoord, {}),                            # Remove all non-coordinate records 
        (biobb_pdb_selres.biobb_pdb_selres,       {'selection': '1:'+str(sel)}),  # Select residues by their range
        (biobb_pdb_tidy.biobb_pdb_tidy,           {})                             # Adhere to the format specifications
    ]

    # Create and launch bb
    pdb_tools_pipeline(pdb_in, pdb_ref[ch], steps)
# Out:
# 2026-01-22 16:55:23,223 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_selchain Version: 5.2.0
# 2026-01-22 16:55:23,225 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_2850be0a-2a3c-4cbc-a964-54dd71ac2a12
# 2026-01-22 16:55:23,226 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4G6M_0.pdb --> sandbox_2850be0a-2a3c-4cbc-a964-54dd71ac2a12
# 2026-01-22 16:55:23,227 [MainThread  ] [INFO ]  Appending chains to select
# 2026-01-22 16:55:23,228 [MainThread  ] [INFO ]  pdb_selchain -H /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_2850be0a-2a3c-4cbc-a964-54dd71ac2a12/4G6M_0.pdb > ./data/antibody/pre/4G6M_H_reduced.pdb
# 2026-01-22 16:55:23,229 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:23,230 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_selchain -H /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_2850be0a-2a3c-4cbc-a964-54dd71ac2a12/4G6M_0.pdb > ./data/antibody/pre/4G6M_H_reduced.pdb
# 2026-01-22 16:55:23,302 [MainThread  ] [INFO ]  Command 'pdb_selchain -H /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_...' finalized with exit code 0
# 2026-01-22 16:55:23,305 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_2850be0a-2a3c-4cbc-a964-54dd71ac2a12']
# 2026-01-22 16:55:23,305 [MainThread  ] [INFO ]
# 2026-01-22 16:55:23,309 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_delhetatm Version: 5.2.0
# 2026-01-22 16:55:23,310 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_28e7cf5d-07d2-4552-acde-b5a1312e6e6b
# 2026-01-22 16:55:23,311 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_28e7cf5d-07d2-4552-acde-b5a1312e6e6b
# 2026-01-22 16:55:23,312 [MainThread  ] [INFO ]  pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_28e7cf5d-07d2-4552-acde-b5a1312e6e6b/tmp.pdb > ./data/antibody/pre/4G6M_H_reduced.pdb
# 2026-01-22 16:55:23,313 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:23,313 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_28e7cf5d-07d2-4552-acde-b5a1312e6e6b/tmp.pdb > ./data/antibody/pre/4G6M_H_reduced.pdb
# 2026-01-22 16:55:23,363 [MainThread  ] [INFO ]  Command 'pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf...' finalized with exit code 0
# 2026-01-22 16:55:23,365 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_28e7cf5d-07d2-4552-acde-b5a1312e6e6b']
# 2026-01-22 16:55:23,366 [MainThread  ] [INFO ]
# 2026-01-22 16:55:23,369 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_fixinsert Version: 5.2.0
# 2026-01-22 16:55:23,370 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_0b3a45c1-eb78-494a-b2a5-d88269681161
# 2026-01-22 16:55:23,371 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_0b3a45c1-eb78-494a-b2a5-d88269681161
# 2026-01-22 16:55:23,372 [MainThread  ] [INFO ]  pdb_fixinsert  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_0b3a45c1-eb78-494a-b2a5-d88269681161/tmp.pdb > ./data/antibody/pre/4G6M_H_reduced.pdb
# 2026-01-22 16:55:23,372 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:23,373 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_fixinsert  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_0b3a45c1-eb78-494a-b2a5-d88269681161/tmp.pdb > ./data/antibody/pre/4G6M_H_reduced.pdb
# 2026-01-22 16:55:23,426 [MainThread  ] [INFO ]  Command 'pdb_fixinsert  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_w...' finalized with exit code 0
# 2026-01-22 16:55:23,429 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_0b3a45c1-eb78-494a-b2a5-d88269681161']
# 2026-01-22 16:55:23,429 [MainThread  ] [INFO ]
# 2026-01-22 16:55:23,433 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_selaltloc Version: 5.2.0
# 2026-01-22 16:55:23,434 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_1074d67b-1317-4794-9f57-de37e1780ef5
# 2026-01-22 16:55:23,435 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_1074d67b-1317-4794-9f57-de37e1780ef5
# 2026-01-22 16:55:23,436 [MainThread  ] [INFO ]  pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_1074d67b-1317-4794-9f57-de37e1780ef5/tmp.pdb > ./data/antibody/pre/4G6M_H_reduced.pdb
# 2026-01-22 16:55:23,437 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:23,437 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_1074d67b-1317-4794-9f57-de37e1780ef5/tmp.pdb > ./data/antibody/pre/4G6M_H_reduced.pdb
# 2026-01-22 16:55:23,495 [MainThread  ] [INFO ]  Command 'pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_w...' finalized with exit code 0
# 2026-01-22 16:55:23,498 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_1074d67b-1317-4794-9f57-de37e1780ef5']
# 2026-01-22 16:55:23,498 [MainThread  ] [INFO ]
# 2026-01-22 16:55:23,501 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_keepcoord Version: 5.2.0
# 2026-01-22 16:55:23,502 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_22a174d2-d7a0-40e8-97b9-dd7f3db85bec
# 2026-01-22 16:55:23,503 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_22a174d2-d7a0-40e8-97b9-dd7f3db85bec
# 2026-01-22 16:55:23,504 [MainThread  ] [INFO ]  pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_22a174d2-d7a0-40e8-97b9-dd7f3db85bec/tmp.pdb > ./data/antibody/pre/4G6M_H_reduced.pdb
# 2026-01-22 16:55:23,505 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:23,505 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_22a174d2-d7a0-40e8-97b9-dd7f3db85bec/tmp.pdb > ./data/antibody/pre/4G6M_H_reduced.pdb
# 2026-01-22 16:55:23,554 [MainThread  ] [INFO ]  Command 'pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf...' finalized with exit code 0
# 2026-01-22 16:55:23,557 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_22a174d2-d7a0-40e8-97b9-dd7f3db85bec']
# 2026-01-22 16:55:23,558 [MainThread  ] [INFO ]
# 2026-01-22 16:55:23,560 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_selres Version: 5.2.0
# 2026-01-22 16:55:23,561 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_a0eeebf1-70f9-42ba-9ca9-0ac609174f66
# 2026-01-22 16:55:23,562 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_a0eeebf1-70f9-42ba-9ca9-0ac609174f66
# 2026-01-22 16:55:23,563 [MainThread  ] [INFO ]  Selecting residues with pattern: 1:120
# 2026-01-22 16:55:23,563 [MainThread  ] [INFO ]  pdb_selres -1:120 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_a0eeebf1-70f9-42ba-9ca9-0ac609174f66/tmp.pdb > ./data/antibody/pre/4G6M_H_reduced.pdb
# 2026-01-22 16:55:23,563 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:23,564 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_selres -1:120 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_a0eeebf1-70f9-42ba-9ca9-0ac609174f66/tmp.pdb > ./data/antibody/pre/4G6M_H_reduced.pdb
# 2026-01-22 16:55:23,628 [MainThread  ] [INFO ]  Command 'pdb_selres -1:120 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biob...' finalized with exit code 0
# 2026-01-22 16:55:23,630 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_a0eeebf1-70f9-42ba-9ca9-0ac609174f66']
# 2026-01-22 16:55:23,631 [MainThread  ] [INFO ]
# 2026-01-22 16:55:23,634 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_tidy Version: 5.2.0
# 2026-01-22 16:55:23,635 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_3177b264-ab2e-4637-9b44-e351e67870cc
# 2026-01-22 16:55:23,636 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_3177b264-ab2e-4637-9b44-e351e67870cc
# 2026-01-22 16:55:23,637 [MainThread  ] [INFO ]  pdb_tidy  tmp.pdb > ./data/antibody/pre/4G6M_H_reduced.pdb
# 2026-01-22 16:55:23,638 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:23,638 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_tidy  tmp.pdb > ./data/antibody/pre/4G6M_H_reduced.pdb
# 2026-01-22 16:55:23,689 [MainThread  ] [INFO ]  Command 'pdb_tidy  tmp.pdb > ./data/antibody/pre/4G6M_H_reduced.pdb...' finalized with exit code 0
# 2026-01-22 16:55:23,692 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_3177b264-ab2e-4637-9b44-e351e67870cc']
# 2026-01-22 16:55:23,692 [MainThread  ] [INFO ]
# 2026-01-22 16:55:23,695 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_selchain Version: 5.2.0
# 2026-01-22 16:55:23,696 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_674b8dd8-e654-43b2-9e31-dd1dc1282887
# 2026-01-22 16:55:23,697 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4G6M_0.pdb --> sandbox_674b8dd8-e654-43b2-9e31-dd1dc1282887
# 2026-01-22 16:55:23,698 [MainThread  ] [INFO ]  Appending chains to select
# 2026-01-22 16:55:23,698 [MainThread  ] [INFO ]  pdb_selchain -L /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_674b8dd8-e654-43b2-9e31-dd1dc1282887/4G6M_0.pdb > ./data/antibody/pre/4G6M_L_reduced.pdb
# 2026-01-22 16:55:23,699 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:23,699 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_selchain -L /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_674b8dd8-e654-43b2-9e31-dd1dc1282887/4G6M_0.pdb > ./data/antibody/pre/4G6M_L_reduced.pdb
# 2026-01-22 16:55:23,749 [MainThread  ] [INFO ]  Command 'pdb_selchain -L /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_...' finalized with exit code 0
# 2026-01-22 16:55:23,751 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_674b8dd8-e654-43b2-9e31-dd1dc1282887']
# 2026-01-22 16:55:23,752 [MainThread  ] [INFO ]
# 2026-01-22 16:55:23,754 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_delhetatm Version: 5.2.0
# 2026-01-22 16:55:23,755 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_6293405a-a659-4729-9ceb-60a5164e09f8
# 2026-01-22 16:55:23,756 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_6293405a-a659-4729-9ceb-60a5164e09f8
# 2026-01-22 16:55:23,757 [MainThread  ] [INFO ]  pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_6293405a-a659-4729-9ceb-60a5164e09f8/tmp.pdb > ./data/antibody/pre/4G6M_L_reduced.pdb
# 2026-01-22 16:55:23,757 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:23,758 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_6293405a-a659-4729-9ceb-60a5164e09f8/tmp.pdb > ./data/antibody/pre/4G6M_L_reduced.pdb
# 2026-01-22 16:55:23,807 [MainThread  ] [INFO ]  Command 'pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf...' finalized with exit code 0
# 2026-01-22 16:55:23,809 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_6293405a-a659-4729-9ceb-60a5164e09f8']
# 2026-01-22 16:55:23,809 [MainThread  ] [INFO ]
# 2026-01-22 16:55:23,812 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_fixinsert Version: 5.2.0
# 2026-01-22 16:55:23,813 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_62201f83-01c2-4e7a-bdf4-5b2cd9a944e0
# 2026-01-22 16:55:23,813 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_62201f83-01c2-4e7a-bdf4-5b2cd9a944e0
# 2026-01-22 16:55:23,816 [MainThread  ] [INFO ]  pdb_fixinsert  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_62201f83-01c2-4e7a-bdf4-5b2cd9a944e0/tmp.pdb > ./data/antibody/pre/4G6M_L_reduced.pdb
# 2026-01-22 16:55:23,816 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:23,817 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_fixinsert  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_62201f83-01c2-4e7a-bdf4-5b2cd9a944e0/tmp.pdb > ./data/antibody/pre/4G6M_L_reduced.pdb
# 2026-01-22 16:55:23,903 [MainThread  ] [INFO ]  Command 'pdb_fixinsert  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_w...' finalized with exit code 0
# 2026-01-22 16:55:23,905 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_62201f83-01c2-4e7a-bdf4-5b2cd9a944e0']
# 2026-01-22 16:55:23,906 [MainThread  ] [INFO ]
# 2026-01-22 16:55:23,909 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_selaltloc Version: 5.2.0
# 2026-01-22 16:55:23,909 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_7a0007f0-ced4-4d5c-8350-fae1a2925fc7
# 2026-01-22 16:55:23,911 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_7a0007f0-ced4-4d5c-8350-fae1a2925fc7
# 2026-01-22 16:55:23,912 [MainThread  ] [INFO ]  pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_7a0007f0-ced4-4d5c-8350-fae1a2925fc7/tmp.pdb > ./data/antibody/pre/4G6M_L_reduced.pdb
# 2026-01-22 16:55:23,912 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:23,913 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_7a0007f0-ced4-4d5c-8350-fae1a2925fc7/tmp.pdb > ./data/antibody/pre/4G6M_L_reduced.pdb
# 2026-01-22 16:55:23,972 [MainThread  ] [INFO ]  Command 'pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_w...' finalized with exit code 0
# 2026-01-22 16:55:23,975 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_7a0007f0-ced4-4d5c-8350-fae1a2925fc7']
# 2026-01-22 16:55:23,975 [MainThread  ] [INFO ]
# 2026-01-22 16:55:23,978 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_keepcoord Version: 5.2.0
# 2026-01-22 16:55:23,979 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_1da7f92e-7c4c-4f49-801b-73b9fed012bb
# 2026-01-22 16:55:23,980 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_1da7f92e-7c4c-4f49-801b-73b9fed012bb
# 2026-01-22 16:55:23,981 [MainThread  ] [INFO ]  pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_1da7f92e-7c4c-4f49-801b-73b9fed012bb/tmp.pdb > ./data/antibody/pre/4G6M_L_reduced.pdb
# 2026-01-22 16:55:23,981 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:23,982 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_1da7f92e-7c4c-4f49-801b-73b9fed012bb/tmp.pdb > ./data/antibody/pre/4G6M_L_reduced.pdb
# 2026-01-22 16:55:24,037 [MainThread  ] [INFO ]  Command 'pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf...' finalized with exit code 0
# 2026-01-22 16:55:24,040 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_1da7f92e-7c4c-4f49-801b-73b9fed012bb']
# 2026-01-22 16:55:24,041 [MainThread  ] [INFO ]
# 2026-01-22 16:55:24,044 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_selres Version: 5.2.0
# 2026-01-22 16:55:24,045 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_ce918fb9-9e4a-41c4-a1b7-ca0834e06733
# 2026-01-22 16:55:24,046 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_ce918fb9-9e4a-41c4-a1b7-ca0834e06733
# 2026-01-22 16:55:24,048 [MainThread  ] [INFO ]  Selecting residues with pattern: 1:107
# 2026-01-22 16:55:24,048 [MainThread  ] [INFO ]  pdb_selres -1:107 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_ce918fb9-9e4a-41c4-a1b7-ca0834e06733/tmp.pdb > ./data/antibody/pre/4G6M_L_reduced.pdb
# 2026-01-22 16:55:24,049 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:24,050 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_selres -1:107 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_ce918fb9-9e4a-41c4-a1b7-ca0834e06733/tmp.pdb > ./data/antibody/pre/4G6M_L_reduced.pdb
# 2026-01-22 16:55:24,115 [MainThread  ] [INFO ]  Command 'pdb_selres -1:107 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biob...' finalized with exit code 0
# 2026-01-22 16:55:24,118 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_ce918fb9-9e4a-41c4-a1b7-ca0834e06733']
# 2026-01-22 16:55:24,119 [MainThread  ] [INFO ]
# 2026-01-22 16:55:24,121 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_tidy Version: 5.2.0
# 2026-01-22 16:55:24,122 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b00dfac1-8d9e-4df9-b8f5-6050c1144102
# 2026-01-22 16:55:24,123 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_b00dfac1-8d9e-4df9-b8f5-6050c1144102
# 2026-01-22 16:55:24,124 [MainThread  ] [INFO ]  pdb_tidy  tmp.pdb > ./data/antibody/pre/4G6M_L_reduced.pdb
# 2026-01-22 16:55:24,125 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:24,125 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_tidy  tmp.pdb > ./data/antibody/pre/4G6M_L_reduced.pdb
# 2026-01-22 16:55:24,178 [MainThread  ] [INFO ]  Command 'pdb_tidy  tmp.pdb > ./data/antibody/pre/4G6M_L_reduced.pdb...' finalized with exit code 0
# 2026-01-22 16:55:24,180 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b00dfac1-8d9e-4df9-b8f5-6050c1144102']
# 2026-01-22 16:55:24,181 [MainThread  ] [INFO ]

# %% [markdown]
# ### [Preparing the Reference structure] Step 2: Merge Heavy and Light regions (from the complex) into a single file
# Merge **both chains** (Heavy, Light) into a single PDB file. <br>
# - *4G6M_antibody_clean.pdb* (Heavy + Light chains, FV)

# %%
# Join the generated PDB files in a single ZIP file 
zip_file_path = f'{out_path}/pre/{complex_pdb}_HL.zip'
# Create a zip file and add the pdb_out file to it
with zipfile.ZipFile(zip_file_path, 'w') as zipf:
    zipf.write(pdb_ref['H'], arcname=f'{complex_pdb}_H.pdb')
    zipf.write(pdb_ref['L'], arcname=f'{complex_pdb}_L.pdb')
    
# Create properties dict and inputs/outputs
complexFile_ref_antibody = f'{out_path}/pre/{complex_pdb}_antibody_clean.pdb' 

# Create and launch bb
biobb_pdb_merge(input_file_path = zip_file_path,  
                output_file_path=complexFile_ref_antibody)
# Out:
# 2026-01-22 16:55:25,261 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_merge Version: 5.2.0
# 2026-01-22 16:55:25,262 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_df3de8b9-8bda-438e-bdb1-992c993c9c1c
# 2026-01-22 16:55:25,263 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4G6M_HL.zip --> sandbox_df3de8b9-8bda-438e-bdb1-992c993c9c1c
# 2026-01-22 16:55:25,267 [MainThread  ] [INFO ]  pdb_merge /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_df3de8b9-8bda-438e-bdb1-992c993c9c1c/4G6M_H.pdb /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_df3de8b9-8bda-438e-bdb1-992c993c9c1c/4G6M_L.pdb > ./data/antibody/pre/4G6M_antibody_clean.pdb
# 2026-01-22 16:55:25,268 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:25,269 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_merge /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_df3de8b9-8bda-438e-bdb1-992c993c9c1c/4G6M_H.pdb /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_df3de8b9-8bda-438e-bdb1-992c993c9c1c/4G6M_L.pdb > ./data/antibody/pre/4G6M_antibody_clean.pdb
# 2026-01-22 16:55:25,332 [MainThread  ] [INFO ]  Command 'pdb_merge /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_had...' finalized with exit code 0
# 2026-01-22 16:55:25,335 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_df3de8b9-8bda-438e-bdb1-992c993c9c1c']
# 2026-01-22 16:55:25,335 [MainThread  ] [INFO ]
# 0

# %% [markdown]
# ### [Preparing the Reference structure] Step 3: Prepare the Antibody PDB file (from the complex) to match HADDOCK3 requirements
# Add **single chain id** to the whole structure, **renumber residue ids**, and add chain id in the **segment identifier**, with the aim of having a **reference PDB** that can be directly compared with the **HADDOCK3** generated models.<br>
# - *4G6M_clean_antibody_final.pdb*

# %%
# Create properties dict and inputs/outputs
complexFile_ref_antibody_final = f'{out_path}/pre/{complex_pdb}_clean_antibody_final.pdb'

steps = [
    (biobb_pdb_reres.biobb_pdb_reres,         {'number': 1}),     # Renumber the residues starting from 1
    (biobb_pdb_chain.biobb_pdb_chain,         {'chain': 'A'}),    # Modify the chain identifier column 
    (biobb_pdb_chainxseg.biobb_pdb_chainxseg, {}),                # Swap the segment identifier for the chain identifier
    (biobb_pdb_tidy.biobb_pdb_tidy,           {'strict': True})   # Adhere to the format specifications
]

# Create and launch bb
pdb_tools_pipeline(complexFile_ref_antibody, complexFile_ref_antibody_final, steps)
# Out:
# 2026-01-22 16:55:27,359 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_reres Version: 5.2.0
# 2026-01-22 16:55:27,360 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f31fffc5-7434-438b-baaa-cfd5311f5700
# 2026-01-22 16:55:27,361 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4G6M_antibody_clean.pdb --> sandbox_f31fffc5-7434-438b-baaa-cfd5311f5700
# 2026-01-22 16:55:27,363 [MainThread  ] [INFO ]  Appending optional boolean property
# 2026-01-22 16:55:27,363 [MainThread  ] [INFO ]  pdb_reres -1 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f31fffc5-7434-438b-baaa-cfd5311f5700/4G6M_antibody_clean.pdb > ./data/antibody/pre/4G6M_clean_antibody_final.pdb
# 2026-01-22 16:55:27,364 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:27,364 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_reres -1 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f31fffc5-7434-438b-baaa-cfd5311f5700/4G6M_antibody_clean.pdb > ./data/antibody/pre/4G6M_clean_antibody_final.pdb
# 2026-01-22 16:55:27,416 [MainThread  ] [INFO ]  Command 'pdb_reres -1 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_...' finalized with exit code 0
# 2026-01-22 16:55:27,419 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f31fffc5-7434-438b-baaa-cfd5311f5700']
# 2026-01-22 16:55:27,419 [MainThread  ] [INFO ]
# 2026-01-22 16:55:27,422 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_chain Version: 5.2.0
# 2026-01-22 16:55:27,423 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_70263f22-b350-451f-9e0d-bd0a508776a8
# 2026-01-22 16:55:27,424 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_70263f22-b350-451f-9e0d-bd0a508776a8
# 2026-01-22 16:55:27,425 [MainThread  ] [INFO ]  Appending optional boolean property
# 2026-01-22 16:55:27,425 [MainThread  ] [INFO ]  pdb_chain -A /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_70263f22-b350-451f-9e0d-bd0a508776a8/tmp.pdb > ./data/antibody/pre/4G6M_clean_antibody_final.pdb
# 2026-01-22 16:55:27,426 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:27,427 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_chain -A /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_70263f22-b350-451f-9e0d-bd0a508776a8/tmp.pdb > ./data/antibody/pre/4G6M_clean_antibody_final.pdb
# 2026-01-22 16:55:27,476 [MainThread  ] [INFO ]  Command 'pdb_chain -A /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_...' finalized with exit code 0
# 2026-01-22 16:55:27,479 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_70263f22-b350-451f-9e0d-bd0a508776a8']
# 2026-01-22 16:55:27,480 [MainThread  ] [INFO ]
# 2026-01-22 16:55:27,483 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_chainxseg Version: 5.2.0
# 2026-01-22 16:55:27,484 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_e9ed7d0c-fd16-47c2-8d06-9722bbba93cd
# 2026-01-22 16:55:27,485 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_e9ed7d0c-fd16-47c2-8d06-9722bbba93cd
# 2026-01-22 16:55:27,487 [MainThread  ] [INFO ]  pdb_chainxseg /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_e9ed7d0c-fd16-47c2-8d06-9722bbba93cd/tmp.pdb > ./data/antibody/pre/4G6M_clean_antibody_final.pdb
# 2026-01-22 16:55:27,487 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:27,488 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_chainxseg /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_e9ed7d0c-fd16-47c2-8d06-9722bbba93cd/tmp.pdb > ./data/antibody/pre/4G6M_clean_antibody_final.pdb
# 2026-01-22 16:55:27,539 [MainThread  ] [INFO ]  Command 'pdb_chainxseg /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf...' finalized with exit code 0
# 2026-01-22 16:55:27,542 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_e9ed7d0c-fd16-47c2-8d06-9722bbba93cd']
# 2026-01-22 16:55:27,543 [MainThread  ] [INFO ]
# 2026-01-22 16:55:27,545 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_tidy Version: 5.2.0
# 2026-01-22 16:55:27,546 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_a9acff6c-b94b-474e-8bf3-10cdf906dab8
# 2026-01-22 16:55:27,547 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_a9acff6c-b94b-474e-8bf3-10cdf906dab8
# 2026-01-22 16:55:27,548 [MainThread  ] [INFO ]  Appending optional boolean property
# 2026-01-22 16:55:27,549 [MainThread  ] [INFO ]  pdb_tidy -strict tmp.pdb > ./data/antibody/pre/4G6M_clean_antibody_final.pdb
# 2026-01-22 16:55:27,549 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:27,550 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_tidy -strict tmp.pdb > ./data/antibody/pre/4G6M_clean_antibody_final.pdb
# 2026-01-22 16:55:27,603 [MainThread  ] [INFO ]  Command 'pdb_tidy -strict tmp.pdb > ./data/antibody/pre/4G6M_clean_antibody_final.pdb...' finalized with exit code 0
# 2026-01-22 16:55:27,606 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_a9acff6c-b94b-474e-8bf3-10cdf906dab8']
# 2026-01-22 16:55:27,606 [MainThread  ] [INFO ]

# %% [markdown]
# ### [Preparing the Reference structure] Step 4: Prepare the Antigen PDB file (from the complex) to match HADDOCK3 requirements
# Add **single chain id** to the whole structure, **renumber residue ids**, and add chain id in the **segment identifier**, with the aim of having a **reference PDB** that can be directly compared with the **HADDOCK3** generated models.<br>
# - *4G6M_clean_antigen_final.pdb*

# %%
# Create properties dict and inputs/outputs
complexFile_ref_antigen_final = f'{out_path}/pre/{complex_pdb}_clean_antigen_final.pdb'

steps = [
    (biobb_pdb_tidy.biobb_pdb_tidy,           {'strict': True}),    # Adhere to the format specifications
    (biobb_pdb_selchain.biobb_pdb_selchain,   {'chains': 'A'}),     # Extract chains
    (biobb_pdb_chain.biobb_pdb_chain,         {'chain': 'B'}),      # Modify the chain identifier column 
    (biobb_pdb_chainxseg.biobb_pdb_chainxseg, {}),                  # Swap the segment identifier for the chain identifier
    (biobb_pdb_delhetatm.biobb_pdb_delhetatm, {}),                  # Remove all HETATM records
    (biobb_pdb_fixinsert.biobb_pdb_fixinsert, {}),                  # Delete insertion codes and shift residue numbering
    (biobb_pdb_selaltloc.biobb_pdb_selaltloc, {}),                  # Select altloc labels (highest occupancy) 
    (biobb_pdb_keepcoord.biobb_pdb_keepcoord, {}),                  # Remove all non-coordinate records 
    (biobb_pdb_tidy.biobb_pdb_tidy,           {'strict': True})     # Adhere to the format specifications
]
# Create and launch bb
pdb_tools_pipeline(cx_pdb, complexFile_ref_antigen_final, steps)
# Out:
# 2026-01-22 16:55:29,151 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_tidy Version: 5.2.0
# 2026-01-22 16:55:29,153 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_9b297bf9-0ad8-4b35-90d0-177476312e79
# 2026-01-22 16:55:29,154 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4G6M_0.pdb --> sandbox_9b297bf9-0ad8-4b35-90d0-177476312e79
# 2026-01-22 16:55:29,156 [MainThread  ] [INFO ]  Appending optional boolean property
# 2026-01-22 16:55:29,156 [MainThread  ] [INFO ]  pdb_tidy -strict ./data/antibody/pre/4G6M_0.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,158 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:29,158 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_tidy -strict ./data/antibody/pre/4G6M_0.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,232 [MainThread  ] [INFO ]  Command 'pdb_tidy -strict ./data/antibody/pre/4G6M_0.pdb > ./data/antibody/pre/4G6M_clean...' finalized with exit code 0
# 2026-01-22 16:55:29,234 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_9b297bf9-0ad8-4b35-90d0-177476312e79']
# 2026-01-22 16:55:29,235 [MainThread  ] [INFO ]
# 2026-01-22 16:55:29,238 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_selchain Version: 5.2.0
# 2026-01-22 16:55:29,239 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_c73f1ef7-857c-447f-a277-3fd71b192979
# 2026-01-22 16:55:29,239 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_c73f1ef7-857c-447f-a277-3fd71b192979
# 2026-01-22 16:55:29,241 [MainThread  ] [INFO ]  Appending chains to select
# 2026-01-22 16:55:29,241 [MainThread  ] [INFO ]  pdb_selchain -A /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_c73f1ef7-857c-447f-a277-3fd71b192979/tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,241 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:29,242 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_selchain -A /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_c73f1ef7-857c-447f-a277-3fd71b192979/tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,291 [MainThread  ] [INFO ]  Command 'pdb_selchain -A /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_...' finalized with exit code 0
# 2026-01-22 16:55:29,294 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_c73f1ef7-857c-447f-a277-3fd71b192979']
# 2026-01-22 16:55:29,294 [MainThread  ] [INFO ]
# 2026-01-22 16:55:29,297 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_chain Version: 5.2.0
# 2026-01-22 16:55:29,298 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_5f9e20be-0d87-47b9-b721-025af040e9c9
# 2026-01-22 16:55:29,299 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_5f9e20be-0d87-47b9-b721-025af040e9c9
# 2026-01-22 16:55:29,300 [MainThread  ] [INFO ]  Appending optional boolean property
# 2026-01-22 16:55:29,301 [MainThread  ] [INFO ]  pdb_chain -B /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_5f9e20be-0d87-47b9-b721-025af040e9c9/tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,301 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:29,302 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_chain -B /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_5f9e20be-0d87-47b9-b721-025af040e9c9/tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,351 [MainThread  ] [INFO ]  Command 'pdb_chain -B /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_...' finalized with exit code 0
# 2026-01-22 16:55:29,354 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_5f9e20be-0d87-47b9-b721-025af040e9c9']
# 2026-01-22 16:55:29,354 [MainThread  ] [INFO ]
# 2026-01-22 16:55:29,357 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_chainxseg Version: 5.2.0
# 2026-01-22 16:55:29,358 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f90520ad-5c46-402d-8a36-5ebb6c33d79a
# 2026-01-22 16:55:29,359 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_f90520ad-5c46-402d-8a36-5ebb6c33d79a
# 2026-01-22 16:55:29,361 [MainThread  ] [INFO ]  pdb_chainxseg /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f90520ad-5c46-402d-8a36-5ebb6c33d79a/tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,361 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:29,362 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_chainxseg /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f90520ad-5c46-402d-8a36-5ebb6c33d79a/tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,408 [MainThread  ] [INFO ]  Command 'pdb_chainxseg /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf...' finalized with exit code 0
# 2026-01-22 16:55:29,411 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f90520ad-5c46-402d-8a36-5ebb6c33d79a']
# 2026-01-22 16:55:29,411 [MainThread  ] [INFO ]
# 2026-01-22 16:55:29,414 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_delhetatm Version: 5.2.0
# 2026-01-22 16:55:29,414 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_687e3404-fc40-4c8c-8bc3-f0eaca3109af
# 2026-01-22 16:55:29,415 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_687e3404-fc40-4c8c-8bc3-f0eaca3109af
# 2026-01-22 16:55:29,416 [MainThread  ] [INFO ]  pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_687e3404-fc40-4c8c-8bc3-f0eaca3109af/tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,416 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:29,417 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_687e3404-fc40-4c8c-8bc3-f0eaca3109af/tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,462 [MainThread  ] [INFO ]  Command 'pdb_delhetatm /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf...' finalized with exit code 0
# 2026-01-22 16:55:29,464 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_687e3404-fc40-4c8c-8bc3-f0eaca3109af']
# 2026-01-22 16:55:29,465 [MainThread  ] [INFO ]
# 2026-01-22 16:55:29,467 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_fixinsert Version: 5.2.0
# 2026-01-22 16:55:29,468 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_35bd36c7-c95b-4654-8535-affbc9f2016e
# 2026-01-22 16:55:29,469 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_35bd36c7-c95b-4654-8535-affbc9f2016e
# 2026-01-22 16:55:29,469 [MainThread  ] [INFO ]  pdb_fixinsert  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_35bd36c7-c95b-4654-8535-affbc9f2016e/tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,470 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:29,470 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_fixinsert  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_35bd36c7-c95b-4654-8535-affbc9f2016e/tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,518 [MainThread  ] [INFO ]  Command 'pdb_fixinsert  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_w...' finalized with exit code 0
# 2026-01-22 16:55:29,520 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_35bd36c7-c95b-4654-8535-affbc9f2016e']
# 2026-01-22 16:55:29,520 [MainThread  ] [INFO ]
# 2026-01-22 16:55:29,523 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_selaltloc Version: 5.2.0
# 2026-01-22 16:55:29,524 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_1c801b75-6f59-4c51-98a2-475761e16e87
# 2026-01-22 16:55:29,524 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_1c801b75-6f59-4c51-98a2-475761e16e87
# 2026-01-22 16:55:29,525 [MainThread  ] [INFO ]  pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_1c801b75-6f59-4c51-98a2-475761e16e87/tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,526 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:29,527 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_1c801b75-6f59-4c51-98a2-475761e16e87/tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,579 [MainThread  ] [INFO ]  Command 'pdb_selaltloc  /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_w...' finalized with exit code 0
# 2026-01-22 16:55:29,581 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_1c801b75-6f59-4c51-98a2-475761e16e87']
# 2026-01-22 16:55:29,582 [MainThread  ] [INFO ]
# 2026-01-22 16:55:29,585 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_keepcoord Version: 5.2.0
# 2026-01-22 16:55:29,585 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_d978655e-5125-40e3-a485-f6c4b0762b4a
# 2026-01-22 16:55:29,586 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_d978655e-5125-40e3-a485-f6c4b0762b4a
# 2026-01-22 16:55:29,587 [MainThread  ] [INFO ]  pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_d978655e-5125-40e3-a485-f6c4b0762b4a/tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,588 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:29,588 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_d978655e-5125-40e3-a485-f6c4b0762b4a/tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,635 [MainThread  ] [INFO ]  Command 'pdb_keepcoord /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf...' finalized with exit code 0
# 2026-01-22 16:55:29,637 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_d978655e-5125-40e3-a485-f6c4b0762b4a']
# 2026-01-22 16:55:29,638 [MainThread  ] [INFO ]
# 2026-01-22 16:55:29,641 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_tidy Version: 5.2.0
# 2026-01-22 16:55:29,641 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_e323d599-bc7f-42e0-8f28-a15e6a6e0515
# 2026-01-22 16:55:29,642 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_e323d599-bc7f-42e0-8f28-a15e6a6e0515
# 2026-01-22 16:55:29,643 [MainThread  ] [INFO ]  Appending optional boolean property
# 2026-01-22 16:55:29,644 [MainThread  ] [INFO ]  pdb_tidy -strict tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,644 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:29,645 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_tidy -strict tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb
# 2026-01-22 16:55:29,693 [MainThread  ] [INFO ]  Command 'pdb_tidy -strict tmp.pdb > ./data/antibody/pre/4G6M_clean_antigen_final.pdb...' finalized with exit code 0
# 2026-01-22 16:55:29,696 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_e323d599-bc7f-42e0-8f28-a15e6a6e0515']
# 2026-01-22 16:55:29,696 [MainThread  ] [INFO ]

# %% [markdown]
# ### [Preparing the Reference structure] Step 5: Merge Heavy + Light regions and Antigen (from the complex) into a single file
# Merge **all chains** (Antibody Heavy chain, Antibody Light chain, Antigen) into a single PDB file. <br>
# - *4G6M_clean.pdb* (Heavy + Light chains -FV- + Antigen)

# %%
## Join the generated PDB files in a single ZIP file ##

zip_file_path = f'{out_path}/pre/{complex_pdb}_HL_B.zip'
# Create a zip file and add the pdb_out file to it
with zipfile.ZipFile(zip_file_path, 'w') as zipf:
    zipf.write(complexFile_ref_antibody_final, arcname=f'{complex_pdb}_antibody.pdb')
    zipf.write(complexFile_ref_antigen_final, arcname=f'{complex_pdb}_antigen.pdb')
    
# Create properties dict and inputs/outputs
complex_prep = f'{out_path}/pre/{complex_pdb}_clean.pdb' 

steps = [
    (biobb_pdb_merge,         {}),                                 # Merges several PDB files into one
    (biobb_pdb_tidy.biobb_pdb_tidy,           {'strict': True})    # Adhere to the format specifications
]

# Create and launch bb
pdb_tools_pipeline(zip_file_path, complex_prep, steps)
# Out:
# 2026-01-22 16:55:31,772 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_merge Version: 5.2.0
# 2026-01-22 16:55:31,773 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_4eb76366-1e4d-40d7-985e-f6ad7a89d443
# 2026-01-22 16:55:31,775 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4G6M_HL_B.zip --> sandbox_4eb76366-1e4d-40d7-985e-f6ad7a89d443
# 2026-01-22 16:55:31,777 [MainThread  ] [INFO ]  pdb_merge /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_4eb76366-1e4d-40d7-985e-f6ad7a89d443/4G6M_antibody.pdb /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_4eb76366-1e4d-40d7-985e-f6ad7a89d443/4G6M_antigen.pdb > ./data/antibody/pre/4G6M_clean.pdb
# 2026-01-22 16:55:31,778 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:31,779 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_merge /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_4eb76366-1e4d-40d7-985e-f6ad7a89d443/4G6M_antibody.pdb /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_4eb76366-1e4d-40d7-985e-f6ad7a89d443/4G6M_antigen.pdb > ./data/antibody/pre/4G6M_clean.pdb
# 2026-01-22 16:55:31,846 [MainThread  ] [INFO ]  Command 'pdb_merge /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_had...' finalized with exit code 0
# 2026-01-22 16:55:31,849 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_4eb76366-1e4d-40d7-985e-f6ad7a89d443']
# 2026-01-22 16:55:31,850 [MainThread  ] [INFO ]
# 2026-01-22 16:55:31,853 [MainThread  ] [INFO ]  Module: biobb_pdb_tools.pdb_tools.biobb_pdb_tidy Version: 5.2.0
# 2026-01-22 16:55:31,853 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_561d1c5d-c1a9-4ba7-8aad-f5b22645aa0d
# 2026-01-22 16:55:31,854 [MainThread  ] [INFO ]  Copy to stage: tmp.pdb --> sandbox_561d1c5d-c1a9-4ba7-8aad-f5b22645aa0d
# 2026-01-22 16:55:31,855 [MainThread  ] [INFO ]  Appending optional boolean property
# 2026-01-22 16:55:31,856 [MainThread  ] [INFO ]  pdb_tidy -strict tmp.pdb > ./data/antibody/pre/4G6M_clean.pdb
# 2026-01-22 16:55:31,856 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2026-01-22 16:55:31,857 [MainThread  ] [INFO ]  Launching command (it may take a while): pdb_tidy -strict tmp.pdb > ./data/antibody/pre/4G6M_clean.pdb
# 2026-01-22 16:55:31,913 [MainThread  ] [INFO ]  Command 'pdb_tidy -strict tmp.pdb > ./data/antibody/pre/4G6M_clean.pdb...' finalized with exit code 0
# 2026-01-22 16:55:31,916 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_561d1c5d-c1a9-4ba7-8aad-f5b22645aa0d']
# 2026-01-22 16:55:31,916 [MainThread  ] [INFO ]

# %% [markdown]
# ### [Preparing the Reference structure] Step 6: Visualize final structure (antibody-antigen complex)
#
# Visualizing the processed **antibody-antigen complex** using **NGLview**:
# - Left: **Original Antibody-Antigen complex** for comparison. Heavy Chain: Green; Light Chain: Blue; Antigen: Red
# - Right: **Processed Antibody-Antigen complex** with only the variable domain (FV). Heavy Chain: Green; Light Chain: Blue; Antigen: Red

# %%
# Show structures: antibody, antigen and complex
view1 = nv.show_structure_file(cx_pdb)
view1._remote_call('setSize', target='Widget', args=['500px','400px'])
view1.clear_representations()
view1.add_representation(repr_type='surface', radius='0.3', selection=':H', color='blue')
view1.add_representation(repr_type='surface', radius='0.3', selection=':L', color='red')
view1.add_representation(repr_type='surface', radius='0.3', selection=':A', color='green')
view1.camera='orthographic'
view2 = nv.show_structure_file(complex_prep)
view2._remote_call('setSize', target='Widget', args=['500px','400px'])
view2.clear_representations()
view2.add_representation(repr_type='surface', radius='0.3', selection='1-120:A', color='blue')
view2.add_representation(repr_type='surface', radius='0.3', selection='121-227:A', color='red')
view2.add_representation(repr_type='surface', radius='0.3', selection=':B', color='green')
view2.camera='orthographic'
ipywidgets.HBox([view1, view2])
# Out:
# HBox(children=(NGLWidget(), NGLWidget()))

# %% [markdown]
# # Defining HADDOCK3 restraints
#
# The **HADDOCK3 protein-protein docking** tool integrates diverse sources of information, including experimental data, biochemical and biophysical insights, bioinformatics predictions, and prior knowledge, to **guide** and **refine** the docking process effectively. In this tutorial, knowledge of the **hypervariable loops** ([CDRs](https://en.wikipedia.org/wiki/Complementarity-determining_region)) on the **antibody**, and **epitope** information identified from **NMR experiments** for the **antigen** will be used to **guide the docking**.
#
# The small part of the **antibody Fv region** that binds the **antigen** is called **paratope**. The part of the **antigen** that binds to an **antibody** is called **epitope** (see image, left). The **paratope** consists of six **highly flexible loops**, known as **complementarity-determining regions** (CDRs) or **hypervariable loops** whose sequence and conformation are altered to bind to different **antigens** (see image, right).
#
# Both regions are going to be used as **HADDOCK3 restrictions** to **guide** the **docking process**.
#
# <table cellspacing="0" cellpadding="0" style="border-collapse: collapse; width: 100%;">
#     <tr style="background: white;">
#         <td style="text-align: center; vertical-align: middle; width: 25%;">
#             <img src="imgs/EpitopeParatope.png" alt="Epitope/Paratope" style="max-width: 100%; height: auto; display: block; margin: auto;">
#             <i>Paratope (Antibody) and Epitope (Antigen) representation<br>
#         </td>
#         <td style="text-align: center; vertical-align: middle; width: 50%;">
#             <img src="imgs/CDRs_reduced.png" alt="CDRs" style="max-width: 100%; height: auto; display: block; margin: auto;">
#             <i>Paratope complementarity-determining regions (CDRs)<br> Figure represented with permissions from the official <a href="https://www.bonvinlab.org/education/HADDOCK3/HADDOCK3-antibody-antigen/#introduction">HADDOCK3 antibody-antigen tutorial</a></i>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Paratope Restraints
#
# Developing new **vaccines** and **antibody therapeutics** is a lengthy process, often spanning several years. **Prediction** and understanding of the **paratope** region (**antibody binding site**) can **accelerate** this timeline and **lower the costs**.
#
# As a result, the research community has developed a wide range of tools to **predict paratope regions** (residues within **hypervariable loops** that play a key role in **antibody-antigen binding**) directly from **antibody sequences**.
#
# This tutorial will work with a list of **paratope residues** obtained using the **ProABC-2 predictor** (see reference). **ProABC-2** uses a **convolutional neural network** to identify not only residues which are located in the **paratope region** but also the nature of interactions they are most likely involved in (hydrophobic or hydrophilic).
#
# **Paratope residues** used are those with either an **overall probability >= 0.4** or a **probability for hydrophobic or hydrophilic > 0.3**. Residue numbering corresponding to the processed file: *4G6K_clean.pdb*
#
# References: <br>
#
# **proABC-2: PRediction of AntiBody contacts v2 and its application to information-driven docking.**<br>
# *F. Ambrosetti, T. H. Olsen, P. P. Olimpieri, B. Jiménez-García, E. Milanetti, P. Marcatilli, A. MJJ Bonvin*<br>
# *Bioinformatics, 2020;36(20):5107-5108.*<br>
# *Available at: https://doi.org/10.1093/bioinformatics/btaa644*<br>
# *Source Code: https://github.com/haddocking/proabc-2*
# ***

# %%
# Antibody paratope residue list from proABC-2
paratope_sel = '31,32,33,34,35,52,54,55,56,100,101,102,103,104,105,106,151,152,169,170,173,211,212,213,214,216'

# %%
# Show antibody paratope
view = nv.show_structure_file(antibody_prep)
view._remote_call('setSize', target='Widget', args=['500px','500px'])
view.add_representation(repr_type='surface', selection=paratope_sel.replace(',', ', '), color='#a271a2')
centered_view = ipywidgets.HBox([view], layout=ipywidgets.Layout(justify_content="center"))
centered_view
# Out:
# HBox(children=(NGLWidget(),), layout=Layout(justify_content='center'))

# %% [markdown]
# ### Epitope Restraints
#
# The work describing the **crystal structures** deposited in the **PDB** for the **gevokizumab antibody** (PDB: 4G6K) and the **antibody-antigen** (Gevokizumab-Interleukin1β) complex (PDB: 4G6M) also comes with experimental **NMR chemical shift** titration experiments to map the **binding site** of the antibody on **Interleukin1β**. The residues affected by binding are listed in Table 5 of Blech et al. JMB 2013 (see references below).
#
# References: <br>
#
# **One Target—Two Different Binding Modes: Structural Insights into Gevokizumab and Canakinumab Interactions to Interleukin-1β.**<br>
# *M. Blech, D. Peter, P Fischer, M. M.T. Bauer, M. Hafner, M. Zeeb, H. Nar*<br>
# *Journal of Molecular Biology, 2013;425(1):94-111.*<br>
# *Available at: https://doi.org/10.1016/j.jmb.2012.09.021*
# ***

# %%
# Antigen Epitope residue list from Blech et al. JMB 2013, Table 5
epitope_sel  = '72,73,74,75,81,83,84,89,90,92,94,96,97,98,115,116,117'

# %%
# Show antigen epitope
view = nv.show_structure_file(antigen_prep)
view._remote_call('setSize', target='Widget', args=['500px','400px'])
view.add_representation(repr_type='surface', selection=epitope_sel.replace(',', ', '), color='#a9d18e')
centered_view = ipywidgets.HBox([view], layout=ipywidgets.Layout(justify_content="center"))
centered_view
# Out:
# HBox(children=(NGLWidget(),), layout=Layout(justify_content='center'))

# %% [markdown]
# ### Visualize interfaces (paratope, epitope)
#
# Visualizing the **predicted paratope** and the **described epitope** using **NGLview**:
# - Left: **predicted paratope** (light purple), with only the antibody variable domain (Fv).
# - Center: **described epitope** (light green), with the antigen.
# - Right: **predicted paratope** (light purple) and  **described epitope** (light green) shown on the reference. **Antibody-Antigen complex** with only the variable domain (Fv). Antibody Fv: Blue; Antigen: Green.

# %%
# Show structures:
# Antibody
view1 = nv.show_structure_file(antibody_prep)
view1._remote_call('setSize', target='Widget', args=['350px','400px'])
view1.clear_representations()
view1.add_representation(repr_type='cartoon', selection=':A', color='purple')
view1.add_representation(repr_type='surface', ratio='0.3', selection=paratope_sel.replace(',', ', '), color='#a271a2')
view1.camera='orthographic'
# Antigen
view2 = nv.show_structure_file(antigen_prep)
view2._remote_call('setSize', target='Widget', args=['350px','400px'])
view2.clear_representations()
view2.add_representation(repr_type='cartoon', selection=':B', color='green')
view2.add_representation(repr_type='surface', ratio='0.3', selection=epitope_sel.replace(',', ', '), color='#a9d18e')
view2.camera='orthographic'
# Complex (for reference)
view3 = nv.show_structure_file(complex_prep)
view3._remote_call('setSize', target='Widget', args=['350px','400px'])
view3.clear_representations()
paratope_sel_ngl = ' '.join(f"{num}:A" for num in paratope_sel.split(','))
view3.add_representation(repr_type='cartoon', selection=':A', color='purple')
view3.add_representation(repr_type='surface', ratio='0.3', selection=paratope_sel_ngl, color='#a271a2')
epitope_sel_ngl = ' '.join(f"{num}:B" for num in epitope_sel.split(','))
view3.add_representation(repr_type='cartoon', selection=':B', color='green')
view3.add_representation(repr_type='surface', ratio='0.3', selection=epitope_sel_ngl, color='#a9d18e')
view3.camera='orthographic'
ipywidgets.HBox([view1, view2, view3])
# Out:
# HBox(children=(NGLWidget(), NGLWidget(), NGLWidget()))

# %% [markdown]
# ### HADDOCK3 passive restraints
#
# **Binding site interfaces** defined in the previous steps are tagged as **active residues** in **HADDOCK3**. Additionaly, **HADDOCK3** also gives the possibility to define **passive residues** to refine potentially **incomplete binding sites**. These residues are selected based on the **surface neighbors** of the **active residues**, and are included in the **interface definition**. However, they do not incur any **energetic penalty** if they are not part of the binding site in the final models. In contrast, **active residues** (typically identified or predicted as **key binding site residues**) are subject to an **energetic penalty** if they are not part of the binding site in the final models.
#
# Here is the **HADDOCK3 definition** of **active** and **passive** residues:
#
# **Active residues**: These residues are “forced” to be at the interface. If they are not part of the interface in the final models, an energetic penalty will be applied. The interface in this context is defined by the union of active and passive residues on the partner molecules.
#
# **Passive residues**: These residues are expected to be at the interface. However, if they are not, no energetic penalty is applied.
#
# In **HADDOCK3**, **passive** and **active residues** are defined in a **specific file** containing two lines:
#
# - The first line corresponds to the list of **active residues** (numbers separated by spaces)
# - The second line corresponds to the list of **passive residues** (numbers separated by spaces).
#
# The file must always consist of two lines, but a line can be empty (e.g., if you do not want to define **active or passive residues** for one molecule). However, there must be at least one set of **active residues** defined for one of the molecules.
#
# In this tutorial, a list of **passive residues** are defined for the **epitope region**, whereas no **passive residues** are going to be added to the **paratope region**, using only the **active residues** to guide the **docking process**.
#
# ***
# **Building Blocks** used:
#  - [haddock3_passive_from_active](https://biobb-haddock.readthedocs.io/en/latest/haddock_restraints.html#module-haddock_restraints.haddock3_passive_from_active) from **biobb_haddock.haddock_restraints.haddock3_passive_from_active**
# ***

# %%
# Defining only active residues for antibody paratope region 
# Adding empty line as passive residues
ab_actpass = f'{out_path}/pre/{antibody_pdb}_actpass.txt' 
with open(ab_actpass, 'w') as f:
    f.write( paratope_sel.replace(',', ' ')+'\n\n')

# %%
# For the antigen, we will use the epitope selection as the active selection
# and some reidues around it as passsive

from biobb_haddock.haddock_restraints.haddock3_passive_from_active import haddock3_passive_from_active

# Create properties dict and inputs/outputs
ag_actpass = f'{out_path}/pre/{antigen_pdb}_actpass.txt'

prop = {'active_list' : epitope_sel}

# Create and launch bb
haddock3_passive_from_active( 
    input_pdb_path      = antigen_prep,
    output_actpass_path = ag_actpass,
    properties          = prop
)
# Out:
# 2026-01-22 16:55:42,776 [MainThread  ] [INFO ]  Module: biobb_haddock.haddock_restraints.haddock3_passive_from_active Version: 5.2.0
# 2026-01-22 16:55:42,777 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_57f3d325-8aa5-4045-82d4-e1279eac5141
# 2026-01-22 16:55:42,779 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4I1B_clean.pdb --> sandbox_57f3d325-8aa5-4045-82d4-e1279eac5141
# 2026-01-22 16:55:42,781 [MainThread  ] [INFO ]  Launching command (it may take a while): haddock3-restraints passive_from_active /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_57f3d325-8aa5-4045-82d4-e1279eac5141/4I1B_clean.pdb 72,73,74,75,81,83,84,89,90,92,94,96,97,98,115,116,117 > /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_57f3d325-8aa5-4045-82d4-e1279eac5141/4I1B_actpass.txt 2>&1
# 2026-01-22 16:55:43,396 [MainThread  ] [INFO ]  Command 'haddock3-restraints passive_from_active /Users/gbayarri/projects/BioBB/tutorials...' finalized with exit code 0
# 2026-01-22 16:55:43,398 [MainThread  ] [INFO ]  Result: 3 24 46 47 48 50 66 76 77 79 80 82 86 87 88 91 93 95 118 119 120
#
# 2026-01-22 16:55:43,400 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_57f3d325-8aa5-4045-82d4-e1279eac5141']
# 0

# %% [markdown]
# ### Visualize active / passive residues (epitope)
#
# Visualizing the defined **active** (red) and **passive** (green) residues for the **antigen epitope region** using **NGLview**

# %%
display_actpass(antigen_prep, ag_actpass)
# Out:
# NGLWidget(layout=Layout(width='100%'))

# %% [markdown]
# ### HADDOCK3 ambiguous restraints
#
# Once **active** and **passive residues** are identified and defined for both molecules, they need to be transformed into CNS-formatted **Ambiguous Interaction Restraints** (AIR) files, so that they can be integrated in the **docking process**.
#
# **HADDOCK3** uses **CNS** as computational engine. A description of the format for the various restraint types supported by **HADDOCK3** can be found in the **Nature Protocol HADDOCK paper**, 2024, Box 1 (see reference below).
#
# References: <br>
#
# **The HADDOCK2.4 web server for integrative modeling of biomolecular complexes.**<br>
# *R. Honorato et al.*<br>
# *Nat. Protoc., 2024, 19, 3219–3241.*<br>
# *Available at: https://doi.org/10.1038/s41596-024-01011-0*
# ***
#
# **Building Blocks** used:
#  - [haddock3_actpass_to_ambig](https://biobb-haddock.readthedocs.io/en/latest/haddock_restraints.html#module-haddock_restraints.haddock3_actpass_to_ambig) from **biobb_haddock.haddock_restraints.haddock3_actpass_to_ambig**
# ***

# %%
# Convert active/passive to ambiguous restraints
from biobb_haddock.haddock_restraints.haddock3_actpass_to_ambig import haddock3_actpass_to_ambig

# Create properties dict and inputs/outputs
complex_tbl = f'{out_path}/pre/ambig-paratope-NMR-epitope.tbl'

prop = {
    'segid_one': 'A', 
    'segid_two': 'B'
}

# Create and launch bb
haddock3_actpass_to_ambig( 
    input_actpass1_path=ab_actpass,
    input_actpass2_path=ag_actpass,    
    output_tbl_path=complex_tbl,
    properties = prop
)
# Out:
# 2026-01-22 16:55:46,390 [MainThread  ] [INFO ]  Module: biobb_haddock.haddock_restraints.haddock3_actpass_to_ambig Version: 5.2.0
# 2026-01-22 16:55:46,392 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b149dbe3-4173-4d01-a5c5-6cde1f418f16
# 2026-01-22 16:55:46,394 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4G6K_actpass.txt --> sandbox_b149dbe3-4173-4d01-a5c5-6cde1f418f16
# 2026-01-22 16:55:46,397 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4I1B_actpass.txt --> sandbox_b149dbe3-4173-4d01-a5c5-6cde1f418f16
# 2026-01-22 16:55:46,399 [MainThread  ] [INFO ]  Launching command (it may take a while): haddock3-restraints active_passive_to_ambig /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b149dbe3-4173-4d01-a5c5-6cde1f418f16/4G6K_actpass.txt /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b149dbe3-4173-4d01-a5c5-6cde1f418f16/4I1B_actpass.txt --segid-one A --segid-two B > /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b149dbe3-4173-4d01-a5c5-6cde1f418f16/ambig-paratope-NMR-epitope.tbl 2>&1
# 2026-01-22 16:55:46,927 [MainThread  ] [INFO ]  Command 'haddock3-restraints active_passive_to_ambig /Users/gbayarri/projects/BioBB/tutor...' finalized with exit code 0
# 2026-01-22 16:55:46,930 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_b149dbe3-4173-4d01-a5c5-6cde1f418f16']
# 0

# %% [markdown]
# ### Additional restraints for multi-chain proteins
#
# As an **antibody** consists of two separate chains, it is important to define a few **distance restraints** to keep them together during the high temperature **flexible refinement** stage of **HADDOCK3** otherwise they might slightly drift appart.
#
# The following step generates **CA-CA distance restraints** with the exact distance measured between **randomly picked CA atoms pairs**, which will keep the two chains together.
#
# ***
#
# **Building Blocks** used:
#  - [haddock3_restrain_bodies](https://biobb-haddock.readthedocs.io/en/latest/haddock_restraints.html#module-haddock_restraints.haddock3_restrain_bodies) from **biobb_haddock.haddock_restraints.haddock3_restrain_bodies**
# ***

# %%
# Tie antibody chains together
from biobb_haddock.haddock_restraints.haddock3_restrain_bodies import haddock3_restrain_bodies

# Create properties dict and inputs/outputs
body_tbl = f'{out_path}/pre/antibody-unambig.tbl'

# Create and launch bb
haddock3_restrain_bodies( 
    input_structure_path=antibody_prep,
    output_tbl_path=body_tbl
)
# Out:
# 2026-01-22 16:55:47,709 [MainThread  ] [INFO ]  Module: biobb_haddock.haddock_restraints.haddock3_restrain_bodies Version: 5.2.0
# 2026-01-22 16:55:47,710 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f6fb3481-4824-4b04-b7aa-f49893fabb7c
# 2026-01-22 16:55:47,713 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4G6K_clean.pdb --> sandbox_f6fb3481-4824-4b04-b7aa-f49893fabb7c
# 2026-01-22 16:55:47,714 [MainThread  ] [INFO ]  Launching command (it may take a while): haddock3-restraints restrain_bodies /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f6fb3481-4824-4b04-b7aa-f49893fabb7c/4G6K_clean.pdb > /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f6fb3481-4824-4b04-b7aa-f49893fabb7c/antibody-unambig.tbl 2>&1
# 2026-01-22 16:55:48,235 [MainThread  ] [INFO ]  Command 'haddock3-restraints restrain_bodies /Users/gbayarri/projects/BioBB/tutorials/bio...' finalized with exit code 0
# 2026-01-22 16:55:48,237 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_f6fb3481-4824-4b04-b7aa-f49893fabb7c']
# 0

# %% [markdown]
# # Docking
#
#
# **HADDOCK3** introduced a new **modular version** of the original **HADDOCK**, broken down in a catalogue of independent modules and then enriched with powerful analysis tools and third-party integrations (https://github.com/haddocking/haddock3, see reference below). In **HADDOCK3**, users have the freedom to configure **docking workflows** into functional pipelines by combining the different modules, thus adapting the **workflows** to their projects. **HADDOCK3** has therefore developed to truthfully work like a puzzle of many pieces (simulation modules) that users can combine freely. In the following cells, **BioBB building blocks** wrapping these independent modules are used to build a **HADDOCK3 docking workflow**, step by step. If you are interested in the **HADDOCK3 complete workflow** configuration file, please refer to the [official HADDOCK3 antibody-antigen tutorial section](https://www.bonvinlab.org/education/HADDOCK3/HADDOCK3-antibody-antigen/#haddock3-workflow-definition).
#
# <div align="center">
#     <img src="imgs/HADDOCK3-workflow-scheme.png" alt="HADDOCK3 modularity" title="HADDOCK3 modularity" width="700"/>
#     <br><i>HADDOCK3 workflow modularity<br>Figure represented with permissions from the official
#     <a href="https://www.bonvinlab.org/education/HADDOCK3/HADDOCK3-antibody-antigen/#introduction">HADDOCK3 antibody-antigen tutorial</a></i>
#     <br><br>
# </div>
#
# The **docking workflow** consists of **14 steps**, outlined below. Since this is a **demonstration workflow**, and given the availability of reliable information on the **paratope** and **epitope**, the sampling steps have been reduced. This optimization minimizes computational cost and accelerates time-to-results while maintaining the accuracy of the generated models.
#
# [**1. Create topology**](#1.-Create-topology): Generates the topologies for the CNS engine and builds missing atoms<br>
# [**2. Rigid Body sampling**](#2.-Rigid-Body-sampling): Preforms rigid body energy minimization<br>
# [**3. 1st CAPRI evaluation**](#3.-1st-CAPRI-evaluation): Calculates CAPRI metrics (i-RMSD, l-RMSD, Fnat, DockQ) with respect to the reference structure (complex)<br>
# [**4. Select Top structures**](#4.-Select-Top-structures): Selects the top X models from the previous module<br>
# [**5. Flexible Refinement**](#5.-Flexible-Refinement): Preforms semi-flexible refinement of the interface<br>
# [**6. 2nd CAPRI evaluation**](#6.-2nd-CAPRI-evaluation): Calculates CAPRI metrics with the models generated in the previous step<br>
# [**7. Energy minimization refinement**](#7.-Energy-minimization-refinement): Final refinement by energy minimization<br>
# [**8. 3rd CAPRI evaluation**](#8.-3rd-CAPRI-evaluation): Calculates CAPRI metrics with the models generated in the previous step<br>
# [**9. Clustering**](#9.-Clustering): Clustering of models based on the *Fraction of Common Contacts* (FCC)<br>
# [**10. Selecting top clusters**](#10.-Selecting-top-clusters): Selects the top models of all clusters<br>
# [**11. Final CAPRI evaluation**](#11.-Final-CAPRI-evaluation): Calculates CAPRI metrics with the models generated in the previous step<br>
# [**12. Contacts analysis**](#12.-Contacts-analysis): Contacts analysis of intermolecular contacts<br>
# [**13. Docking Results**](#13.-Docking-Results): Visualize a summary of the final models with statistics and energies<br>
#
#
# To know more about the HADDOCK3 modules, please refer to the [**HADDOCK3 modules documentation**](https://www.bonvinlab.org/haddock3/modules/index.html)
#
# References: <br>
#
# **HADDOCK3: A modular and versatile platform for integrative modelling of biomolecular complexes.**<br>
# *M. Giulini, V. Reys, J.M.C. Teixeira, B. Jiménez-García, R. V. Honorato, A. Kravchenko, X. Xu, R. Versini, A. Engel, S. Verhoeven, A. M.J.J. Bonvin*<br>
# *BioArxiv, 2025*<br>
# *Available at: https://doi.org/10.1101/2025.04.30.651432*
# ***

# %%
# Important variables to remember; those storing file names needed for the Docking process

# antibody_prep  --> Processed antibody PDB file
# antigen_prep --> Processed antigen PDB file
# complex_prep --> Processed antibody-antigen complex PDB file

# complex_tbl --> HADDOCK paratope/epitope restraints (AIR file)
# body_tbl --> HADDOCK multi-body restraints

# %% [markdown]
# ***
# ### 1. Create topology
#
# Create the **CNS all-atom topology**: CNS compatible parameters (.param) and topologies (.psf) for each of the input structures. Detects **missing atoms**, including **hydrogen atoms**, re-builds them when missing, builds and writes out **topologies** (psf) and **coordinates** (PDB) files.
#
# This module is a **pre-requisite** to run any downstream steps and so is often used as the first module in a **HADDOCK3 workflow**.
#
# ***
# **Building Blocks** used:
#  - [topology](https://biobb-haddock.readthedocs.io/en/latest/haddock.html#module-haddock.topology) from **biobb_haddock.haddock.topology**
# ***
# Corresponding **HADDOCK3 module**:
#  - [topo_aa](https://www.bonvinlab.org/haddock3/modules/topology/haddock.modules.topology.topoaa.html) from **topology_modules**
# ***

# %%
from biobb_haddock.haddock.topology import topology
step_nb = 1

# Create properties dict and inputs/outputs
haddock_wf_data = f'{out_path}/docking/haddock_wf_data'
mol1_output_top_zip_path = f'{out_path}/docking/step_outputs/{step_nb}_top_mol1.zip'
mol2_output_top_zip_path = f'{out_path}/docking/step_outputs/{step_nb}_top_mol2.zip'

# Create and launch bb
topology(mol1_input_pdb_path        = antibody_prep,
         mol2_input_pdb_path        = antigen_prep,
         mol1_output_top_zip_path   = mol1_output_top_zip_path,
         mol2_output_top_zip_path   = mol2_output_top_zip_path,
         output_haddock_wf_data     = haddock_wf_data)
# Out:
# 2026-01-22 16:55:51,556 [MainThread  ] [INFO ]  Module: biobb_haddock.haddock.topology Version: 5.2.0
# 2026-01-22 16:55:51,559 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_33a8fa29-42a5-4545-8f8c-a134137beaf5
# 2026-01-22 16:55:51,561 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4G6K_clean.pdb --> sandbox_33a8fa29-42a5-4545-8f8c-a134137beaf5
# 2026-01-22 16:55:51,562 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/4I1B_clean.pdb --> sandbox_33a8fa29-42a5-4545-8f8c-a134137beaf5
# 2026-01-22 16:55:51,564 [MainThread  ] [INFO ]  Launching command (it may take a while): haddock3 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_33a8fa29-42a5-4545-8f8c-a134137beaf5/00a66e28-8b81-4317-886d-37924b837ac0_haddock.cfg
# 2026-01-22 16:56:00,469 [MainThread  ] [INFO ]  Command 'haddock3 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_hadd...' finalized with exit code 0
# 2026-01-22 16:56:00,470 [MainThread  ] [INFO ]  [2026-01-22 16:55:55,398 cli INFO]
# ##############################################
# #                                            #
# #                 HADDOCK3                   #
# #                                            #
# ##############################################
#
# !! Some of the HADDOCK3 components use CNS (Crystallographic and NMR System) which is free of use for non-profit applications. !!
# !! For commercial use it is your own responsibility to have a proper license. !!
# !! For details refer to the DISCLAIMER file in the HADDOCK3 repository. !!
#
# Starting HADDOCK3 v2025.5.0 on 2026-01-22 16:55:00
#
# Python 3.12.12 | packaged by conda-forge | (main, Oct 22 2025, 23:28:53) [Clang 19.1.7 ]
#
# [2026-01-22 16:55:55,577 libworkflow INFO] Reading instructions step 0_topoaa
# [2026-01-22 16:55:55,605 base_cns_module INFO] Running [topoaa] module
# [2026-01-22 16:55:55,605 __init__ INFO] [topoaa] Molecule 1: 4G6K_clean.pdb
# [2026-01-22 16:55:55,608 __init__ INFO] [topoaa] Sanitizing molecule 4G6K_clean.pdb
# [2026-01-22 16:55:55,616 __init__ INFO] [topoaa] Topology CNS input created
# [2026-01-22 16:55:55,616 __init__ INFO] [topoaa] Molecule 2: 4I1B_clean.pdb
# [2026-01-22 16:55:55,618 __init__ INFO] [topoaa] Sanitizing molecule 4I1B_clean.pdb
# [2026-01-22 16:55:55,623 __init__ INFO] [topoaa] Topology CNS input created
# [2026-01-22 16:55:55,623 __init__ INFO] [topoaa] Running CNS Jobs n=2
# [2026-01-22 16:55:55,623 libutil INFO] Selected 2 cores to process 2 jobs, with 8 maximum available cores.
# [2026-01-22 16:55:55,640 libparallel INFO] Using 2 cores
# [2026-01-22 16:55:57,786 libparallel INFO] 2 tasks finished
# [2026-01-22 16:55:57,787 __init__ INFO] [topoaa] CNS jobs have finished
# [2026-01-22 16:55:57,790 base_cns_module INFO] Module [topoaa] finished.
# [2026-01-22 16:55:57,790 __init__ INFO] [topoaa] took 2 seconds
# [2026-01-22 16:55:57,790 clean_steps INFO] Cleaning output for '0_topoaa' using 4 cores.
# [2026-01-22 16:56:00,356 libtimer INFO] cleaning output files took 3 seconds
# [2026-01-22 16:56:00,357 cli INFO] This HADDOCK3 run took: 5 seconds
# [2026-01-22 16:56:00,357 greetings INFO] Your feedback matters in Haddock3! Share your experience and help us grow:
# [2026-01-22 16:56:00,357 greetings INFO] GitHub issues: https://github.com/haddocking/haddock3/issues
# [2026-01-22 16:56:00,357 greetings INFO] BioExcel feedback: https://www.bonvinlab.org/feedback
# [2026-01-22 16:56:00,357 greetings INFO] BioExcel survey: https://bioexcel.eu/bioexcel-survey-2025/
# [2026-01-22 16:56:00,357 greetings INFO] BioExcel forum: https://ask.bioexcel.eu/c/haddock/6
# [2026-01-22 16:56:00,357 cli INFO] Finished at 22/01/2026 16:56:00. Good bye! Adéu-siau! Adiós!
#
# 2026-01-22 16:56:00,474 [MainThread  ] [INFO ]  Adding:
# 2026-01-22 16:56:00,474 [MainThread  ] [INFO ]  ['sandbox_33a8fa29-42a5-4545-8f8c-a134137beaf5/haddock_wf_data/0_topoaa/4I1B_clean_haddock.pdb.gz']
# 2026-01-22 16:56:00,475 [MainThread  ] [INFO ]  to: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/data/antibody/docking/step_outputs/1_top_mol2.zip
# 2026-01-22 16:56:00,475 [MainThread  ] [INFO ]  Copy directory to host: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_33a8fa29-42a5-4545-8f8c-a134137beaf5/haddock_wf_data --> data/antibody/docking/haddock_wf_data
# 2026-01-22 16:56:00,482 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_33a8fa29-42a5-4545-8f8c-a134137beaf5']
# 0

# %% [markdown]
# ***
# ### 2. Rigid Body sampling
#
# **Randomization of orientations** and **rigid-body minimization**. Interacting partners are treated as **rigid bodies**, meaning that all geometrical parameters such as **bond lengths, bond angles, and dihedral angles** are **frozen**. The partners are first separated in space and randomly rotated around their respective centres of mass. Afterwards, the molecules are brought together by **rigid-body energy minimization** with rotations and translation as the only degrees of freedom.
#
# The **driving force** for this **energy minimization** is the **energy function**, which consists of the **intermolecular van der Waals** and **electrostatic energy** terms and the **restraints** defined to **guide** the docking. The definition of those **restraints** is particularly important as they effectively **guide** the minimization process. For example, with a stringent set of **AIRs** or **unambiguous distance restraints**, the solutions of the minimization will **converge** much better and the **sampling** can be limited. In **ab-initio mode**, however, very diverse solutions will be obtained and the **sampling** should be **increased** to make sure to sample enough the possible **interaction space**.
#
# In this case, **restraints** generated in the previous section (**epitope/paratope** and **multi-chain protein**) will be used to **guide** the **rigid body sampling**.
#
# ***
# **Building Blocks** used:
#  - [rigid_body](https://biobb-haddock.readthedocs.io/en/latest/haddock.html#module-haddock.rigid_body) from **biobb_haddock.haddock.rigid_body**
# ***
# Corresponding **HADDOCK3 module**:
#  - [rigidbody](https://www.bonvinlab.org/haddock3/modules/sampling/haddock.modules.sampling.rigidbody.html) from **sampling_modules**
# ***

# %%
# !conda list
# Out:
# # packages in environment at /Users/gbayarri/miniconda3/envs/biobb_wf_haddock:
# #
# # Name                    Version                   Build  Channel
# _openmp_mutex             4.5                  7_kmp_llvm    conda-forge
# _python_abi3_support      1.0                  hd8ed1ab_2    conda-forge
# ambertools                24.8            cuda_None_nompi_py312h9f183f7_101    conda-forge
# amberutils                21.0                     pypi_0    pypi
# anyio                     4.12.1             pyhcf101f3_0    conda-forge
# appnope                   0.1.4              pyhd8ed1ab_1    conda-forge
# argon2-cffi               25.1.0             pyhd8ed1ab_0    conda-forge
# argon2-cffi-bindings      25.1.0          py312h80b0991_2    conda-forge
# arpack                    3.9.1           nompi_hdfe9103_102    conda-forge
# arrow                     1.4.0              pyhcf101f3_0    conda-forge
# asttokens                 3.0.1              pyhd8ed1ab_0    conda-forge
# async-lru                 2.1.0              pyhcf101f3_0    conda-forge
# attrs                     25.4.0             pyhcf101f3_1    conda-forge
# babel                     2.17.0             pyhd8ed1ab_0    conda-forge
# backports.zstd            1.3.0           py312h6917036_0    conda-forge
# beautifulsoup4            4.14.3             pyha770c72_0    conda-forge
# biobb_common              5.2.0              pyhdfd78af_0    bioconda
# biobb_haddock             5.2.0              pyhdfd78af_0    bioconda
# biobb_io                  5.2.0              pyhdfd78af_0    bioconda
# biobb_pdb_tools           5.2.0              pyhdfd78af_0    bioconda
# biopython                 1.86            py312h1a1c95f_1    conda-forge
# bleach                    6.3.0              pyhcf101f3_0    conda-forge
# bleach-with-css           6.3.0                h5f6438b_0    conda-forge
# blosc                     1.21.6               hd145fbb_1    conda-forge
# brotli                    1.2.0                hf139dec_1    conda-forge
# brotli-bin                1.2.0                h8616949_1    conda-forge
# brotli-python             1.2.0           py312h4b46afd_1    conda-forge
# bzip2                     1.0.8                h500dc9f_8    conda-forge
# c-ares                    1.34.6               hb5e19a0_0    conda-forge
# ca-certificates           2026.1.4             hbd8a1cb_0    conda-forge
# cached-property           1.5.2                hd8ed1ab_1    conda-forge
# cached_property           1.5.2              pyha770c72_1    conda-forge
# cachetools                6.2.4              pyhd8ed1ab_0    conda-forge
# certifi                   2026.1.4           pyhd8ed1ab_0    conda-forge
# cffi                      2.0.0           py312he90777b_1    conda-forge
# chardet                   5.2.0              pyhd8ed1ab_3    conda-forge
# charset-normalizer        3.4.4              pyhd8ed1ab_0    conda-forge
# colorama                  0.4.6              pyhd8ed1ab_1    conda-forge
# comm                      0.2.3              pyhe01879c_0    conda-forge
# contourpy                 1.3.3           py312hd099df3_3    conda-forge
# cpython                   3.12.12         py312hd8ed1ab_1    conda-forge
# cycler                    0.12.1             pyhcf101f3_2    conda-forge
# debugpy                   1.8.18          py312hbfd3414_0    conda-forge
# decorator                 5.2.1              pyhd8ed1ab_0    conda-forge
# defusedxml                0.7.1              pyhd8ed1ab_0    conda-forge
# distlib                   0.4.0              pyhd8ed1ab_0    conda-forge
# edgembar                  3.0                      pypi_0    pypi
# exceptiongroup            1.3.1              pyhd8ed1ab_0    conda-forge
# executing                 2.2.1              pyhd8ed1ab_0    conda-forge
# fftw                      3.3.10          nompi_h871bbb0_111    conda-forge
# filelock                  3.20.3             pyhd8ed1ab_0    conda-forge
# fonttools                 4.61.1          py312hacf3034_0    conda-forge
# fqdn                      1.5.1              pyhd8ed1ab_1    conda-forge
# freesasa                  2.2.1                hd8ed1ab_5    conda-forge
# freesasa-python           2.2.1           py312h2f459f6_1    conda-forge
# freetype                  2.14.1               h694c41f_0    conda-forge
# h11                       0.16.0             pyhcf101f3_1    conda-forge
# h2                        4.3.0              pyhcf101f3_0    conda-forge
# haddock_biobb             2025.5          py312h692437a_3    bioconda
# hdf4                      4.2.15               h8138101_7    conda-forge
# hdf5                      1.14.6          nompi_h4b07496_105    conda-forge
# hpack                     4.1.0              pyhd8ed1ab_0    conda-forge
# httpcore                  1.0.9              pyh29332c3_0    conda-forge
# httpx                     0.28.1             pyhd8ed1ab_0    conda-forge
# hyperframe                6.1.0              pyhd8ed1ab_0    conda-forge
# icu                       75.1                 h120a0e1_0    conda-forge
# idna                      3.11               pyhd8ed1ab_0    conda-forge
# importlib-metadata        8.7.0              pyhe01879c_1    conda-forge
# importlib_resources       6.5.2              pyhd8ed1ab_0    conda-forge
# ipykernel                 7.1.0              pyh5552912_0    conda-forge
# ipython                   9.9.0              pyh53cf698_0    conda-forge
# ipython_pygments_lexers   1.1.1              pyhd8ed1ab_0    conda-forge
# ipywidgets                8.1.8              pyhd8ed1ab_0    conda-forge
# isoduration               20.11.0            pyhd8ed1ab_1    conda-forge
# jedi                      0.19.2             pyhd8ed1ab_1    conda-forge
# jinja2                    3.1.6              pyhcf101f3_1    conda-forge
# joblib                    1.5.3              pyhd8ed1ab_0    conda-forge
# json5                     0.13.0             pyhd8ed1ab_0    conda-forge
# jsonpickle                4.1.1              pyhe01879c_0    conda-forge
# jsonpointer               3.0.0              pyhcf101f3_3    conda-forge
# jsonschema                4.26.0             pyhcf101f3_0    conda-forge
# jsonschema-specifications 2025.9.1           pyhcf101f3_0    conda-forge
# jsonschema-with-format-nongpl 4.26.0               hcf101f3_0    conda-forge
# jupyter                   1.1.1              pyhd8ed1ab_1    conda-forge
# jupyter-lsp               2.3.0              pyhcf101f3_0    conda-forge
# jupyter_client            8.8.0              pyhcf101f3_0    conda-forge
# jupyter_console           6.6.3              pyhd8ed1ab_1    conda-forge
# jupyter_core              5.9.1              pyhc90fa1f_0    conda-forge
# jupyter_events            0.12.0             pyh29332c3_0    conda-forge
# jupyter_server            2.17.0             pyhcf101f3_0    conda-forge
# jupyter_server_terminals  0.5.4              pyhcf101f3_0    conda-forge
# jupyterlab                4.5.2              pyhd8ed1ab_0    conda-forge
# jupyterlab_pygments       0.3.0              pyhd8ed1ab_2    conda-forge
# jupyterlab_server         2.28.0             pyhcf101f3_0    conda-forge
# jupyterlab_widgets        3.0.16             pyhcf101f3_1    conda-forge
# kaleido-core              0.2.1                h0d85af4_0    conda-forge
# kiwisolver                1.4.9           py312h90e26e8_2    conda-forge
# krb5                      1.21.3               h37d8d59_0    conda-forge
# lark                      1.3.1              pyhd8ed1ab_0    conda-forge
# lcms2                     2.18                 h90db99b_0    conda-forge
# lerc                      4.0.0                hcca01a6_1    conda-forge
# libaec                    1.1.4                ha6bc127_0    conda-forge
# libblas                   3.11.0          5_he492b99_openblas    conda-forge
# libboost                  1.86.0               hb2bbd1d_4    conda-forge
# libbrotlicommon           1.2.0                h8616949_1    conda-forge
# libbrotlidec              1.2.0                h8616949_1    conda-forge
# libbrotlienc              1.2.0                h8616949_1    conda-forge
# libcblas                  3.11.0          5_h9b27e0a_openblas    conda-forge
# libcurl                   8.18.0               h9348e2b_0    conda-forge
# libcxx                    21.1.8               h3d58e20_0    conda-forge
# libdeflate                1.25                 h517ebb2_0    conda-forge
# libedit                   3.1.20250104    pl5321ha958ccf_0    conda-forge
# libev                     4.33                 h10d778d_2    conda-forge
# libexpat                  2.7.3                heffb93a_0    conda-forge
# libffi                    3.5.2                h750e83c_0    conda-forge
# libfreetype               2.14.1               h694c41f_0    conda-forge
# libfreetype6              2.14.1               h6912278_0    conda-forge
# libgcc                    15.2.0              h08519bb_15    conda-forge
# libgfortran               15.2.0              h7e5c614_15    conda-forge
# libgfortran5              15.2.0              hd16e46c_15    conda-forge
# libiconv                  1.18                 h57a12c2_2    conda-forge
# libjpeg-turbo             3.1.2                h8616949_0    conda-forge
# liblapack                 3.11.0          5_h859234e_openblas    conda-forge
# liblzma                   5.8.2                h11316ed_0    conda-forge
# libnetcdf                 4.9.2           nompi_h6054f6d_118    conda-forge
# libnghttp2                1.67.0               h3338091_0    conda-forge
# libopenblas               0.3.30          openmp_h6006d49_4    conda-forge
# libpng                    1.6.54               h07817ec_0    conda-forge
# libsodium                 1.0.20               hfdf4475_0    conda-forge
# libsqlite                 3.51.2               hb99441e_0    conda-forge
# libssh2                   1.11.1               hed3591d_0    conda-forge
# libtiff                   4.7.1                ha0a348c_1    conda-forge
# libwebp-base              1.6.0                hb807250_0    conda-forge
# libxcb                    1.17.0               hf1f96e2_0    conda-forge
# libxml2                   2.13.9               he1bc88e_0    conda-forge
# libzip                    1.11.2               h31df5bb_0    conda-forge
# libzlib                   1.3.1                hd23fc13_2    conda-forge
# llvm-openmp               21.1.8               h472b3d1_0    conda-forge
# lz4-c                     1.10.0               h240833e_1    conda-forge
# markupsafe                3.0.3           py312hacf3034_0    conda-forge
# mathjax                   2.7.7                h694c41f_3    conda-forge
# matplotlib-base           3.10.8          py312h7894933_0    conda-forge
# matplotlib-inline         0.2.1              pyhd8ed1ab_0    conda-forge
# mistune                   3.2.0              pyhcf101f3_0    conda-forge
# mmpbsa-py                 16.0                     pypi_0    pypi
# munkres                   1.1.4              pyhd8ed1ab_1    conda-forge
# narwhals                  2.15.0             pyhcf101f3_0    conda-forge
# nbclient                  0.10.4             pyhd8ed1ab_0    conda-forge
# nbconvert-core            7.16.6             pyhcf101f3_1    conda-forge
# nbformat                  5.10.4             pyhd8ed1ab_1    conda-forge
# ncurses                   6.5                  h0622a9a_3    conda-forge
# nest-asyncio              1.6.0              pyhd8ed1ab_1    conda-forge
# netcdf-fortran            4.6.2           nompi_h015bb1b_101    conda-forge
# nglview                   3.1.4              pyh620948e_0    conda-forge
# notebook                  7.5.2              pyhcf101f3_0    conda-forge
# notebook-shim             0.2.4              pyhd8ed1ab_1    conda-forge
# numpy                     2.4.1           py312hb34da66_0    conda-forge
# openjpeg                  2.5.4                h87e8dc5_0    conda-forge
# openssl                   3.6.0                h230baf5_0    conda-forge
# overrides                 7.7.0              pyhd8ed1ab_1    conda-forge
# packaging                 25.0               pyh29332c3_1    conda-forge
# packmol-memgen            2025.1.29                pypi_0    pypi
# pandas                    3.0.0           py312hc7bc305_0    conda-forge
# pandocfilters             1.5.0              pyhd8ed1ab_0    conda-forge
# parmed                    4.3.0           py312h9a1398e_1    conda-forge
# parso                     0.8.5              pyhcf101f3_0    conda-forge
# pdb-tools                 2.5.0              pyhd8ed1ab_1    conda-forge
# pdb4amber                 22.0                     pypi_0    pypi
# perl                      5.32.1          7_h10d778d_perl5    conda-forge
# pexpect                   4.9.0              pyhd8ed1ab_1    conda-forge
# pillow                    12.1.0          py312h4985050_0    conda-forge
# pip                       25.3               pyh8b19718_0    conda-forge
# platformdirs              4.5.1              pyhcf101f3_0    conda-forge
# plotly                    6.5.2              pyhd8ed1ab_0    conda-forge
# pluggy                    1.6.0              pyhf9edf01_1    conda-forge
# prometheus_client         0.24.1             pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.52             pyha770c72_0    conda-forge
# prompt_toolkit            3.0.52               hd8ed1ab_0    conda-forge
# psutil                    7.2.1           py312hf7082af_0    conda-forge
# pthread-stubs             0.4               h00291cd_1002    conda-forge
# ptyprocess                0.7.0              pyhd8ed1ab_1    conda-forge
# pure_eval                 0.2.3              pyhd8ed1ab_1    conda-forge
# pycparser                 2.22               pyh29332c3_1    conda-forge
# pygments                  2.19.2             pyhd8ed1ab_0    conda-forge
# pymsmt                    22.0                     pypi_0    pypi
# pyobjc-core               12.1            py312h4a480f0_0    conda-forge
# pyobjc-framework-cocoa    12.1            py312h1993040_0    conda-forge
# pyparsing                 3.3.2              pyhcf101f3_0    conda-forge
# pyproject-api             1.10.0             pyhcf101f3_0    conda-forge
# pysocks                   1.7.1              pyha55dd90_7    conda-forge
# python                    3.12.12         h74c2667_1_cpython    conda-forge
# python-dateutil           2.9.0.post0        pyhe01879c_2    conda-forge
# python-fastjsonschema     2.21.2             pyhe01879c_0    conda-forge
# python-gil                3.12.12              hd8ed1ab_1    conda-forge
# python-json-logger        2.0.7              pyhd8ed1ab_0    conda-forge
# python-tzdata             2025.3             pyhd8ed1ab_0    conda-forge
# python_abi                3.12                    8_cp312    conda-forge
# pytraj                    2.0.6                    pypi_0    pypi
# pytz                      2025.2             pyhd8ed1ab_0    conda-forge
# pyyaml                    6.0.3           py312hacf3034_0    conda-forge
# pyzmq                     27.1.0          py312hb7d603e_0    conda-forge
# qhull                     2020.2               h3c5361c_5    conda-forge
# readline                  8.3                  h68b038d_0    conda-forge
# referencing               0.37.0             pyhcf101f3_0    conda-forge
# requests                  2.32.5             pyhcf101f3_1    conda-forge
# rfc3339-validator         0.1.4              pyhd8ed1ab_1    conda-forge
# rfc3986-validator         0.1.1              pyh9f0ad1d_0    conda-forge
# rfc3987-syntax            1.1.0              pyhe01879c_1    conda-forge
# rpds-py                   0.30.0          py312h8a6388b_0    conda-forge
# sander                    22.0                     pypi_0    pypi
# scipy                     1.17.0          py312ha20b133_1    conda-forge
# send2trash                2.1.0              pyh5552912_0    conda-forge
# setuptools                80.10.1            pyh332efcf_0    conda-forge
# six                       1.17.0             pyhe01879c_1    conda-forge
# snappy                    1.2.2                h01f5ddf_1    conda-forge
# sniffio                   1.3.1              pyhd8ed1ab_2    conda-forge
# soupsieve                 2.8.3              pyhd8ed1ab_0    conda-forge
# stack_data                0.6.3              pyhd8ed1ab_1    conda-forge
# terminado                 0.18.1             pyhc90fa1f_1    conda-forge
# tinycss2                  1.5.1              pyhcf101f3_0    conda-forge
# tk                        8.6.13               hf689a15_3    conda-forge
# toml                      0.10.2             pyhcf101f3_3    conda-forge
# tomli                     2.4.0              pyhcf101f3_0    conda-forge
# tornado                   6.5.3           py312h80b0991_0    conda-forge
# tox                       4.34.1             pyhcf101f3_0    conda-forge
# traitlets                 5.14.3             pyhd8ed1ab_1    conda-forge
# typing-extensions         4.15.0               h396c80c_0    conda-forge
# typing_extensions         4.15.0             pyhcf101f3_0    conda-forge
# typing_utils              0.1.0              pyhd8ed1ab_1    conda-forge
# tzdata                    2025c                hc9c84f9_1    conda-forge
# unicodedata2              17.0.0          py312h80b0991_1    conda-forge
# uri-template              1.3.0              pyhd8ed1ab_1    conda-forge
# urllib3                   2.6.3              pyhd8ed1ab_0    conda-forge
# virtualenv                20.36.1            pyhd8ed1ab_0    conda-forge
# wcwidth                   0.2.14             pyhd8ed1ab_0    conda-forge
# webcolors                 25.10.0            pyhd8ed1ab_0    conda-forge
# webencodings              0.5.1              pyhd8ed1ab_3    conda-forge
# websocket-client          1.9.0              pyhd8ed1ab_0    conda-forge
# wheel                     0.45.1             pyhd8ed1ab_1    conda-forge
# widgetsnbextension        4.0.15             pyhd8ed1ab_0    conda-forge
# xorg-libice               1.1.2                h6e16a3a_0    conda-forge
# xorg-libsm                1.2.6                h6e16a3a_0    conda-forge
# xorg-libx11               1.8.12               h217831a_0    conda-forge
# xorg-libxau               1.0.12               h8616949_1    conda-forge
# xorg-libxdmcp             1.1.5                h8616949_1    conda-forge
# xorg-libxext              1.3.6                h00291cd_0    conda-forge
# xorg-libxt                1.3.1                h6e16a3a_0    conda-forge
# yaml                      0.2.5                h4132b18_3    conda-forge
# zeromq                    4.3.5                h6c33b1e_9    conda-forge
# zipp                      3.23.0             pyhcf101f3_1    conda-forge
# zlib                      1.3.1                hd23fc13_2    conda-forge
# zlib-ng                   2.3.2                h8bce59a_1    conda-forge
# zstd                      1.5.7                h3eecb57_6    conda-forge

# %%
from biobb_haddock.haddock.rigid_body import rigid_body
step_nb = 2
step_backup(2)

# Create properties dict and inputs/outputs
docking_output_zip_path = f'{out_path}/docking/step_outputs/{step_nb}_docking.zip'

prop={
    'cfg': {
        'sampling': 10, # Reduced sampling (10 instead of the default of 1000)
        #'sampling': 50, # Reduced sampling (50 instead of the default of 1000)
        #'sampling': 100, # Reduced sampling (100 instead of the default of 1000)
        'clean': False   # Not compressing generated PDB files
    },
}

# Create and launch bb
rigid_body(input_haddock_wf_data         = haddock_wf_data,
           output_haddock_wf_data        = haddock_wf_data,
           docking_output_zip_path       = docking_output_zip_path,
           ambig_restraints_table_path   = complex_tbl,
           unambig_restraints_table_path = body_tbl,
           properties                    = prop
)
# Out:
# 2026-01-22 16:56:05,894 [MainThread  ] [INFO ]  Module: biobb_haddock.haddock.rigid_body Version: 5.2.0
# 2026-01-22 16:56:05,895 [MainThread  ] [INFO ]  Directory successfully created: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_6db3cb7f-f850-4305-a968-8cb060793138
# 2026-01-22 16:56:05,897 [MainThread  ] [INFO ]  Copy to stage: data/antibody/docking/haddock_wf_data --> sandbox_6db3cb7f-f850-4305-a968-8cb060793138
# 2026-01-22 16:56:05,902 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/ambig-paratope-NMR-epitope.tbl --> sandbox_6db3cb7f-f850-4305-a968-8cb060793138
# 2026-01-22 16:56:05,904 [MainThread  ] [INFO ]  Copy to stage: data/antibody/pre/antibody-unambig.tbl --> sandbox_6db3cb7f-f850-4305-a968-8cb060793138
# 2026-01-22 16:56:05,905 [MainThread  ] [INFO ]  CFG from properties: sampling = 10
# 2026-01-22 16:56:05,906 [MainThread  ] [INFO ]  CFG from properties: clean = False
# 2026-01-22 16:56:05,907 [MainThread  ] [INFO ]  CFG from properties: ambig_fname = /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_6db3cb7f-f850-4305-a968-8cb060793138/ambig-paratope-NMR-epitope.tbl
# 2026-01-22 16:56:05,908 [MainThread  ] [INFO ]  CFG from properties: unambig_fname = /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_6db3cb7f-f850-4305-a968-8cb060793138/antibody-unambig.tbl
# 2026-01-22 16:56:05,908 [MainThread  ] [INFO ]  CFG: postprocess = False
# 2026-01-22 16:56:05,910 [MainThread  ] [INFO ]  Launching command (it may take a while): haddock3 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_6db3cb7f-f850-4305-a968-8cb060793138/12602a80-a955-4441-9e18-1a7538b9fa5f_haddock.cfg --extend-run /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_6db3cb7f-f850-4305-a968-8cb060793138/haddock_wf_data
# 2026-01-22 16:56:12,537 [MainThread  ] [INFO ]  Command 'haddock3 /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_hadd...' finalized with exit code 1
# 2026-01-22 16:56:12,539 [MainThread  ] [INFO ]  [2026-01-22 16:56:06,726 cli INFO]
# ##############################################
# #                                            #
# #                 HADDOCK3                   #
# #                                            #
# ##############################################
#
# !! Some of the HADDOCK3 components use CNS (Crystallographic and NMR System) which is free of use for non-profit applications. !!
# !! For commercial use it is your own responsibility to have a proper license. !!
# !! For details refer to the DISCLAIMER file in the HADDOCK3 repository. !!
#
# Starting HADDOCK3 v2025.5.0 on 2026-01-22 16:56:00
#
# Python 3.12.12 | packaged by conda-forge | (main, Oct 22 2025, 23:28:53) [Clang 19.1.7 ]
#
# [2026-01-22 16:56:06,733 prepare_run INFO] Uncompressing previous output files for folders: 0_topoaa
# [2026-01-22 16:56:09,267 libworkflow INFO] Reading instructions step 1_rigidbody
# [2026-01-22 16:56:09,868 base_cns_module INFO] Running [rigidbody] module
# [2026-01-22 16:56:09,870 __init__ INFO] [rigidbody] crossdock=true
# [2026-01-22 16:56:09,870 __init__ INFO] [rigidbody] Preparing jobs...
# [2026-01-22 16:56:09,872 libutil INFO] Selected 4 cores to process 10 jobs, with 8 maximum available cores.
# [2026-01-22 16:56:09,872 libparallel INFO] Using 4 cores
# [2026-01-22 16:56:10,825 libparallel INFO] 10 tasks finished
# [2026-01-22 16:56:10,827 __init__ INFO] [rigidbody] Preparation took 0.956757 seconds
# [2026-01-22 16:56:10,828 __init__ INFO] [rigidbody] Running CNS Jobs n=10
# [2026-01-22 16:56:10,828 libutil INFO] Selected 4 cores to process 10 jobs, with 8 maximum available cores.
# [2026-01-22 16:56:10,828 libparallel INFO] Using 4 cores
# [2026-01-22 16:56:12,422 libparallel INFO] 10 tasks finished
# [2026-01-22 16:56:12,422 __init__ INFO] [rigidbody] CNS jobs have finished
# [2026-01-22 16:56:12,425 libutil ERROR] 100.00% of output was not generated for this module and tolerance was set to 20.00%.
# Traceback (most recent call last):
#   File "/Users/gbayarri/miniconda3/envs/biobb_wf_haddock/lib/python3.12/site-packages/haddock/libs/libutil.py", line 378, in log_error_and_exit
#     yield
#   File "/Users/gbayarri/miniconda3/envs/biobb_wf_haddock/lib/python3.12/site-packages/haddock/clis/cli.py", line 193, in main
#     workflow.run()
#   File "/Users/gbayarri/miniconda3/envs/biobb_wf_haddock/lib/python3.12/site-packages/haddock/gear/extend_run.py", line 46, in run
#     step.execute()
#   File "/Users/gbayarri/miniconda3/envs/biobb_wf_haddock/lib/python3.12/site-packages/haddock/libs/libworkflow.py", line 173, in execute
#     self.module.run()  # type: ignore
#     ^^^^^^^^^^^^^^^^^
#   File "/Users/gbayarri/miniconda3/envs/biobb_wf_haddock/lib/python3.12/site-packages/haddock/modules/base_cns_module.py", line 61, in run
#     self._run()
#   File "/Users/gbayarri/miniconda3/envs/biobb_wf_haddock/lib/python3.12/site-packages/haddock/modules/sampling/rigidbody/__init__.py", line 250, in _run
#     self.export_io_models(faulty_tolerance=self.params["tolerance"])
#   File "/Users/gbayarri/miniconda3/envs/biobb_wf_haddock/lib/python3.12/site-packages/haddock/modules/__init__.py", line 309, in export_io_models
#     self.finish_with_error(_msg)
#   File "/Users/gbayarri/miniconda3/envs/biobb_wf_haddock/lib/python3.12/site-packages/haddock/modules/__init__.py", line 317, in finish_with_error
#     raise RuntimeError(reason)
# RuntimeError: 100.00% of output was not generated for this module and tolerance was set to 20.00%.
# [2026-01-22 16:56:12,429 libutil ERROR] 100.00% of output was not generated for this module and tolerance was set to 20.00%.
# [2026-01-22 16:56:12,429 libutil ERROR] An error has occurred, see log file. And contact the developers if needed.
# [2026-01-22 16:56:12,429 libutil INFO] Finished at 22/01/2026 16:56:12. For any help contact us at https://github.com/haddocking/haddock3/issues. Até logo! Au revoir! Good bye!.
#
# 2026-01-22 16:56:12,541 [MainThread  ] [INFO ]  No output files found matching the criteria.
# 2026-01-22 16:56:12,541 [MainThread  ] [INFO ]  Copy directory to host: /Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_6db3cb7f-f850-4305-a968-8cb060793138/haddock_wf_data --> data/antibody/docking/haddock_wf_data
# 2026-01-22 16:56:12,548 [MainThread  ] [INFO ]  Removed: ['/Users/gbayarri/projects/BioBB/tutorials/biobb_wf_haddock/biobb_wf_haddock/notebooks/sandbox_6db3cb7f-f850-4305-a968-8cb060793138']
# 1

# %% [markdown]
# ***
# ### 3. 1st CAPRI evaluation
#
# **CAPRI (Critical Assessment of PRedicted Interactions)** is a community wide initiative for testing computational algorithms in **blind predictions** of experimentally determined 3D structures of **protein complexes**, the “targets”, provided to **CAPRI** prior to publication.
#
# This step calculates **metrics** used during the **CAPRI evaluation process** (i-RMSD, l-RMSD, Fnat, DockQ) with respect to the **reference structure** (complex).
#
# ***
# **Building Blocks** used:
#  - [capri_eval](https://biobb-haddock.readthedocs.io/en/latest/haddock.html#module-haddock.capri_eval) from **biobb_haddock.haddock.capri_eval**
# ***
# Corresponding **HADDOCK3 module**:
#  - [caprieval](https://www.bonvinlab.org/haddock3/modules/analysis/haddock.modules.analysis.caprieval.html) from **analysis_modules**
# ***

# %%
from biobb_haddock.haddock.capri_eval import capri_eval
step_nb = 3
step_backup(3)
# Create properties dict and inputs/outputs
output_evaluation_zip_path = f'{out_path}/docking/step_outputs/{step_nb}_caprieval.zip'

# Create and launch bb
capri_eval(input_haddock_wf_data      = haddock_wf_data,
           output_haddock_wf_data     = haddock_wf_data,
           reference_pdb_path         = complex_prep,
           output_evaluation_zip_path = output_evaluation_zip_path)

# %%
# Looking at the cluster-based (clt) and single-structure (ss) CAPRI evaluation outputs
tsv_dir = haddock_wf_data + '/2_caprieval/'

# Load the cluster and single data into pandas DataFrames
cluster_df = pandas.read_csv(tsv_dir + 'capri_clt.tsv', sep='\t',comment='#')
single_df = pandas.read_csv(tsv_dir + 'capri_ss.tsv', sep='\t',comment='#')

# Align reference to models
model = os.path.normpath(os.path.join(tsv_dir, "../1_rigidbody/rigidbody_1.pdb"))

ref_sup_A = f"{out_path}/aligned_reference_A.pdb"
ref_sup_B = f"{out_path}/aligned_reference_B.pdb"
superpose_ref(model, complex_prep, ref_sup_A, "A")
superpose_ref(model, complex_prep, ref_sup_B, "B")

# Align generated models by chain
input_path = f'{haddock_wf_data}/1_rigidbody'
for chain in ["A","B"]:
    output_file = f"{out_path}/aligned_ensemble_{chain}.pdb"
    superpose_models(chain,input_path,output_file)

# Show results
aligned_ensemble_A = f"{out_path}/aligned_ensemble_A.pdb"
aligned_ensemble_B = f"{out_path}/aligned_ensemble_B.pdb"
capri_visualization(aligned_ensemble_A,aligned_ensemble_B,ref_sup_A,ref_sup_B,input_path,single_df,cluster_df)

# %%
# Open HADDOCK CAPRI evaluation results summary (browser) 
capri_analysis_path = f'{haddock_wf_data}/analysis/2_caprieval_analysis/report.html'
open_results_mod(capri_analysis_path)

# %% [markdown]
# ***
# ### 4. Select Top structures
#
# Select a **number of structures** from the input models. By default, the selection is based on the **HADDOCK score** of the models. The number of models to be selected is defined by the ***select*** parameter. In the standard **HADDOCK protocol**, this number is **200**, which can be increased if more models should be refined.
#
# ***
# **Building Blocks** used:
#  - [sele_top](https://biobb-haddock.readthedocs.io/en/latest/haddock.html#module-haddock.sele_top) from **biobb_haddock.haddock.sele_top**
# ***
# Corresponding **HADDOCK3 module**:
#  - [seletop](https://www.bonvinlab.org/haddock3/modules/analysis/haddock.modules.analysis.seletop.html) from **analysis_modules**
# ***

# %%
from biobb_haddock.haddock.sele_top import sele_top
step_nb = 4
step_backup(4)
# Create properties dict and inputs/outputs
output_selection_zip_path = f'{out_path}/docking/step_outputs/{step_nb}_selected.zip'

prop={
    'cfg': {
        'select': 8,  # Selection of the top 8 best scoring complexes (instead of the default of 200)
        #'select': 20,  # Selection of the top 20 best scoring complexes (instead of the default of 200)
    }
}

# Create and launch bb
sele_top(input_haddock_wf_data     = haddock_wf_data,
         output_haddock_wf_data    = haddock_wf_data,
         output_selection_zip_path = output_selection_zip_path,
         properties                = prop)

# %% [markdown]
# ***
# ### 5. Flexible Refinement
#
# **Flexible refinement** with **CNS**, a **semi-flexible simulated annealing** (SA) protocol based on molecular dynamics in **torsion angle** space.
#
# This refinement consists of several stages:
#
# - High temperature rigid body molecular dynamics
# - Rigid body SA
# - Semi-flexible SA with flexible side-chains at the interface
# - Semi-flexible SA with fully flexible interface (both backbone and side-chains)
#
# By default, only the **interface regions** are treated as **flexible**, automatically defined based on the **intermolecular contacts**. It is also possible to manually define the **semi-flexible regions**, and also define **fully flexible regions** that are allowed to move throughout the entire protocol from the high temperature rigid body molecular dynamics on. The **temperature** and **number of steps** for the various stages can be tuned.
#
# ***
# **Building Blocks** used:
#  - [flex_ref](https://biobb-haddock.readthedocs.io/en/latest/haddock.html#module-haddock.flex_ref) from **biobb_haddock.haddock.flex_ref**
# ***
# Corresponding **HADDOCK3 module**:
#  - [flexref](https://www.bonvinlab.org/haddock3/modules/refinement/haddock.modules.refinement.flexref.html) from **refinement_modules**
# ***

# %%
from biobb_haddock.haddock.flex_ref import flex_ref
step_nb = 5
step_backup(5)
# Create properties dict and inputs/outputs
refinement_output_zip_path = f'{out_path}/docking/step_outputs/{step_nb}_flexref.zip'

prop={
    'cfg': {
        'tolerance' : 5,   # Failure tolerance percentage
        'clean': False,    # Not compressing generated PDB files
    },
}

# Create and launch bb
flex_ref(input_haddock_wf_data         = haddock_wf_data,
         output_haddock_wf_data        = haddock_wf_data,
         refinement_output_zip_path    = refinement_output_zip_path,
         ambig_restraints_table_path   = complex_tbl,
         unambig_restraints_table_path = body_tbl,
         properties                    = prop)

# %% [markdown]
# ***
# ### 6. 2nd CAPRI evaluation
#
# **CAPRI (Critical Assessment of PRedicted Interactions)** is a community wide initiative for testing computational algorithms in **blind predictions** of experimentally determined 3D structures of **protein complexes**, the “targets”, provided to **CAPRI** prior to publication.
#
# This step calculates **metrics** used during the **CAPRI evaluation process** (i-RMSD, l-RMSD, Fnat, DockQ) with respect to the **reference structure** (complex).
#
# ***
# **Building Blocks** used:
#  - [capri_eval](https://biobb-haddock.readthedocs.io/en/latest/haddock.html#module-haddock.capri_eval) from **biobb_haddock.haddock.capri_eval**
# ***
# Corresponding **HADDOCK3 module**:
#  - [caprieval](https://www.bonvinlab.org/haddock3/modules/analysis/haddock.modules.analysis.caprieval.html) from **analysis_modules**
# ***

# %%
from biobb_haddock.haddock.capri_eval import capri_eval
step_nb = 6
step_backup(6)
# Create properties dict and inputs/outputs
output_evaluation_zip_path2 = f'{out_path}/docking/step_outputs/{step_nb}_caprieval2.zip'

# Create and launch bb
capri_eval(input_haddock_wf_data      = haddock_wf_data,
           output_haddock_wf_data     = haddock_wf_data,
           reference_pdb_path         = complex_prep,
           output_evaluation_zip_path = output_evaluation_zip_path2)

# %%
# Looking at the cluster-based (clt) and single-structure (ss) CAPRI evaluation outputs
tsv_dir = haddock_wf_data + '/5_caprieval/'

# Load the cluster and single data into pandas DataFrames
cluster_df = pandas.read_csv(tsv_dir + 'capri_clt.tsv', sep='\t',comment='#')
single_df = pandas.read_csv(tsv_dir + 'capri_ss.tsv', sep='\t',comment='#')

# Align reference to models
model = os.path.normpath(os.path.join(tsv_dir, "../4_flexref/flexref_1.pdb"))
ref_sup_A = f"{out_path}/aligned_reference_A.pdb"
ref_sup_B = f"{out_path}/aligned_reference_B.pdb"
superpose_ref(model, complex_prep, ref_sup_A, "A")
superpose_ref(model, complex_prep, ref_sup_B, "B")

# Align generated models by chain
input_path = f'{haddock_wf_data}/4_flexref'
for chain in ["A","B"]:
    output_file = f"{out_path}/aligned_ensemble_{chain}.pdb"
    superpose_models(chain,input_path,output_file)

# Show results
aligned_ensemble_A = f"{out_path}/aligned_ensemble_A.pdb"
aligned_ensemble_B = f"{out_path}/aligned_ensemble_B.pdb"
capri_visualization(aligned_ensemble_A,aligned_ensemble_B,ref_sup_A,ref_sup_B,input_path,single_df,cluster_df)

# %%
# Open HADDOCK CAPRI evaluation results summary (browser) 
capri_analysis_path = f'{haddock_wf_data}/analysis/5_caprieval_analysis/report.html'
open_results_mod(capri_analysis_path)

# %% [markdown]
# ***
# ### 7. Energy minimization refinement
#
# **Energy minimization** refinement with **CNS**, refines the input complexes by **energy minimization** using **conjugate gradient** method.
# **Coordinates** of the **energy minimized structures** are saved, and each complex is then evaluated using the **HADDOCK scoring function**.
#
# ***
# **Building Blocks** used:
#  - [em_ref](https://biobb-haddock.readthedocs.io/en/latest/haddock.html#module-haddock.em_ref) from **biobb_haddock.haddock.em_ref**
# ***
# Corresponding **HADDOCK3 module**:
# - [emref](https://www.bonvinlab.org/haddock3/modules/refinement/haddock.modules.refinement.emref.html) from **refinement.modules**

# %%
from biobb_haddock.haddock.em_ref import em_ref
step_nb = 7
step_backup(7)
# Create properties dict and inputs/outputs
refinement_output_zip_path = f'{out_path}/docking/step_outputs/{step_nb}_emref.zip'

prop={
    'cfg': {
        'tolerance' : 5,   # Failure tolerance percentage
        'clean': False,  # Not compressing generated PDB files
    },
}

# Create and launch bb
em_ref(input_haddock_wf_data         = haddock_wf_data,
       output_haddock_wf_data        = haddock_wf_data,
       refinement_output_zip_path    = refinement_output_zip_path,
       ambig_restraints_table_path   = complex_tbl,
       unambig_restraints_table_path = body_tbl,
       properties                    = prop)

# %% [markdown]
# ***
# ### 8. 3rd CAPRI evaluation
#
# **CAPRI (Critical Assessment of PRedicted Interactions)** is a community wide initiative for testing computational algorithms in **blind predictions** of experimentally determined 3D structures of **protein complexes**, the “targets”, provided to **CAPRI** prior to publication.
#
# This step calculates **metrics** used during the **CAPRI evaluation process** (i-RMSD, l-RMSD, Fnat, DockQ) with respect to the **reference structure** (complex).
#
# ***
# **Building Blocks** used:
#  - [capri_eval](https://biobb-haddock.readthedocs.io/en/latest/haddock.html#module-haddock.capri_eval) from **biobb_haddock.haddock.capri_eval**
# ***
# Corresponding **HADDOCK3 module**:
#  - [caprieval](https://www.bonvinlab.org/haddock3/modules/analysis/haddock.modules.analysis.caprieval.html) from **analysis_modules**
# ***

# %%
from biobb_haddock.haddock.capri_eval import capri_eval
step_nb = 8
step_backup(8)
# Create properties dict and inputs/outputs
output_evaluation_zip_path3 = f'{out_path}/docking/step_outputs/{step_nb}_caprieval3.zip'

# Create and launch bb
capri_eval(input_haddock_wf_data      = haddock_wf_data,
           output_haddock_wf_data     = haddock_wf_data,
           reference_pdb_path         = complex_prep,
           output_evaluation_zip_path = output_evaluation_zip_path3)

# %%
# Looking at the cluster-based (clt) and single-structure (ss) CAPRI evaluation outputs
tsv_dir = haddock_wf_data + '/7_caprieval/'

# Load the cluster and single data into pandas DataFrames
cluster_df = pandas.read_csv(tsv_dir + 'capri_clt.tsv', sep='\t',comment='#')
single_df = pandas.read_csv(tsv_dir + 'capri_ss.tsv', sep='\t',comment='#')

# Align reference to models
model = os.path.normpath(os.path.join(tsv_dir, "../6_emref/emref_1.pdb"))
ref_sup_A = f"{out_path}/aligned_reference_A.pdb"
ref_sup_B = f"{out_path}/aligned_reference_B.pdb"
superpose_ref(model, complex_prep, ref_sup_A, "A")
superpose_ref(model, complex_prep, ref_sup_B, "B")

# Align generated models by chain
input_path = f'{haddock_wf_data}/6_emref'
for chain in ["A","B"]:
    output_file = f"{out_path}/aligned_ensemble_{chain}.pdb"
    superpose_models(chain,input_path,output_file)

# Show results
aligned_ensemble_A = f"{out_path}/aligned_ensemble_A.pdb"
aligned_ensemble_B = f"{out_path}/aligned_ensemble_B.pdb"
capri_visualization(aligned_ensemble_A,aligned_ensemble_B,ref_sup_A,ref_sup_B,input_path,single_df,cluster_df)

# %%
# Open HADDOCK CAPRI evaluation results summary (browser) 
capri_analysis_path = f'{haddock_wf_data}/analysis/7_caprieval_analysis/report.html'
open_results_mod(capri_analysis_path)

# %% [markdown]
# ***
# ### 9. Clustering
#
# **Cluster** models with the *Fraction of Common Contacts* (FCC) method. The module takes the models generated in the previous step and calculates the **contacts** between them. Then, calculates the **FCC matrix** and **clusters** the models based on the **calculated contacts**.
#
# References: <br>
#
# **Clustering biomolecular complexes by residue contacts similarity.**<br>
# *J.P.G.L.M. Rodrigues, M. Trellet, C. Schmitz, P. Kastritis, E. Karaca, A.S.J. Melquiond, A.M.J.J. Bonvin.*<br>
# *Proteins, 2012, 80(7),1810-7*<br>
# *Available at: https://doi.org/10.1002/prot.24078*
# ***
# **Building Blocks** used:
#  - [clust_fcc](https://biobb-haddock.readthedocs.io/en/latest/haddock.html#module-haddock.clust_fcc) from **biobb_haddock.haddock.clust_fcc**
# ***
# Corresponding **HADDOCK3 module**:
#  - [clustfcc](https://www.bonvinlab.org/haddock3/modules/analysis/haddock.modules.analysis.clustfcc.html) from **analysis_modules**
# ***

# %%
from biobb_haddock.haddock.clust_fcc import clust_fcc
step_nb = 9
step_backup(9)
# Create properties dict and inputs/outputs
output_cluster_zip_path = f'{out_path}/docking/step_outputs/{step_nb}_clustfcc.zip'

prop={
    'cfg': {
        'plot_matrix' : True,   # Plot matrix of members
    }
}

# Create and launch bb
clust_fcc(input_haddock_wf_data   = haddock_wf_data,
          output_haddock_wf_data  = haddock_wf_data,
          output_cluster_zip_path = output_cluster_zip_path,
          properties              = prop)

# %% [markdown]
# ***
# ### 10. Selecting top clusters
#
# Select **models** from the **top clusters**. The selection is based on the **score** of the models within the clusters.
#
# In the standard **HADDOCK** analysis, the **top 4 models** of the **top 10 clusters** are shown.
#
# ***
# **Building Blocks** used:
#  - [sele_top_clusts](https://biobb-haddock.readthedocs.io/en/latest/haddock.html#module-haddock.sele_top_clusts) from **biobb_haddock.haddock.sele_top_clusts**
# ***
# Corresponding **HADDOCK3 module**:
#  - [seletopclusts](https://www.bonvinlab.org/haddock3/modules/analysis/haddock.modules.analysis.seletopclusts.html) from **analysis_modules**
# ***

# %%
from biobb_haddock.haddock.sele_top_clusts import sele_top_clusts
step_nb = 10
step_backup(10)
# Create properties dict and inputs/outputs
output_seletopclusts_zip_path = f'{out_path}/docking/step_outputs/{step_nb}_seletopclusts.zip'

prop={
    'cfg': {
        'top_models': 4,   # Selection of the top 4 best scoring complexes from each cluster
        'clean': False     # Not compressing generated PDB files
    },
}

# Create and launch bb
sele_top_clusts(input_haddock_wf_data     = haddock_wf_data,
                output_haddock_wf_data    = haddock_wf_data,
                output_selection_zip_path = output_seletopclusts_zip_path,
                properties                = prop)

# %% [markdown]
# ***
# ### 11. Final CAPRI evaluation
#
# **CAPRI (Critical Assessment of PRedicted Interactions)** is a community wide initiative for testing computational algorithms in **blind predictions** of experimentally determined 3D structures of **protein complexes**, the “targets”, provided to **CAPRI** prior to publication.
#
# This step calculates **metrics** used during the **CAPRI evaluation process** (i-RMSD, l-RMSD, Fnat, DockQ) with respect to the **reference structure** (complex).
#
# ***
# **Building Blocks** used:
#  - [capri_eval](https://biobb-haddock.readthedocs.io/en/latest/haddock.html#module-haddock.capri_eval) from **biobb_haddock.haddock.capri_eval**
# ***
# Corresponding **HADDOCK3 module**:
#  - [caprieval](https://www.bonvinlab.org/haddock3/modules/analysis/haddock.modules.analysis.caprieval.html) from **analysis_modules**
# ***

# %%
from biobb_haddock.haddock.capri_eval import capri_eval
step_nb = 11
step_backup(11)
# Create properties dict and inputs/outputs
output_evaluation_zip_path4 = f'{out_path}/docking/step_outputs/{step_nb}_caprieval4.zip'

# Create and launch bb
capri_eval(input_haddock_wf_data      = haddock_wf_data,
           output_haddock_wf_data     = haddock_wf_data,
           reference_pdb_path         = complex_prep,
           output_evaluation_zip_path = output_evaluation_zip_path4)

# %%
# Looking at the cluster-based (clt) and single-structure (ss) CAPRI evaluation outputs
tsv_dir = haddock_wf_data + '/10_caprieval/'

# Load the cluster and single data into pandas DataFrames
cluster_df = pandas.read_csv(tsv_dir + 'capri_clt.tsv', sep='\t',comment='#')
single_df = pandas.read_csv(tsv_dir + 'capri_ss.tsv', sep='\t',comment='#')

# Align reference to models
model = os.path.normpath(os.path.join(tsv_dir, "../09_seletopclusts/cluster_1_model_1.pdb"))
ref_sup_A = f"{out_path}/aligned_reference_A.pdb"
ref_sup_B = f"{out_path}/aligned_reference_B.pdb"
superpose_ref(model, complex_prep, ref_sup_A, "A")
superpose_ref(model, complex_prep, ref_sup_B, "B")

# Align generated models by chain
input_path = f'{haddock_wf_data}/09_seletopclusts'
for chain in ["A","B"]:
    output_file = f"{out_path}/aligned_ensemble_{chain}.pdb"
    superpose_models(chain,input_path,output_file)

# Show results
aligned_ensemble_A = f"{out_path}/aligned_ensemble_A.pdb"
aligned_ensemble_B = f"{out_path}/aligned_ensemble_B.pdb"
capri_visualization(aligned_ensemble_A,aligned_ensemble_B,ref_sup_A,ref_sup_B,input_path,single_df,cluster_df)

# %%
# Open HADDOCK CAPRI evaluation results summary (browser) 
capri_analysis_path = f'{haddock_wf_data}/analysis/10_caprieval_analysis/report.html'
open_results_mod(capri_analysis_path)

# %% [markdown]
# ***
# ### 12. Contacts analysis
#
# Compute **contacts** between chains in complexes, generating **heatmaps** and **chordcharts** of the **contacts** observed in the input complexes. If complexes are **clustered**, the analysis of contacts will be performed based on **all structures** from each **cluster**.
#
# **Heatmaps** are describing the **probability of contacts** (<5A) between two residues (both intramolecular and intermolecular).
#
# **Chordcharts** are describing only **intermolecular contacts in circles**, connecting with chords the two residues that are contacting.
#
# ***
# **Building Blocks** used:
#  - [contact_map](https://biobb-haddock.readthedocs.io/en/latest/haddock.html#module-haddock.contact_map) from **biobb_haddock.haddock.contact_map**
# ***
# Corresponding **HADDOCK3 module**:
#  - [contactmap](https://www.bonvinlab.org/haddock3/modules/analysis/haddock.modules.analysis.contactmap.html) from **analysis_modules**
# ***

# %%
from biobb_haddock.haddock.contact_map import contact_map
step_nb = 12
step_backup(12)
# Create properties dict and inputs/outputs
output_contactmap_zip_path = f'{out_path}/docking/step_outputs/{step_nb}_contact_map.zip'

# Create and launch bb
contact_map(input_haddock_wf_data      = haddock_wf_data,
            output_haddock_wf_data     = haddock_wf_data,
            output_contactmap_zip_path = output_contactmap_zip_path)

# %%
htmls = sorted(glob.glob(haddock_wf_data+'/11_contactmap/cluster*.html'))

contacts = []
for i, m in enumerate(htmls):
    contacts.append(m.split('/')[-1])
    
contact_sel = ipywidgets.Dropdown(
    options=contacts,
    description='Sel. model:',
    label=None,
)
def on_dropdown_change(change):
    """Handle dropdown selection changes.
    From https://github.com/nglviewer/nglview/issues/765
    """
    if change['type'] == 'change' and change['name'] == 'value': 
        contact_map_path = haddock_wf_data+f'/11_contactmap/{change["new"]}'
        print(contact_map_path)
        webbrowser.open(contact_map_path)
        
# Register the callback function
contact_sel.observe(on_dropdown_change, names='value')
contact_sel

# %% [markdown]
# ***
# ### 13. Final Results
#
# **Final results** of the **docking process** contain various steps of the defined **workflow** numbered sequentially starting at 0, e.g.:
#
#      00_topoaa/
#      01_rigidbody/
#      02_caprieval/
#
# In addition, there are four **additional directories** and a **log file**:
#
# - ***analysis directory***: contains various plots to visualize the results for each caprieval step and a general report (report.html) that provides all statistics with various plots (to be opened in your preferred web browser)
# - ***data directory***: contains the input data (PDB and restraint files) for the various modules, as well as an input workflow (in configurations directory)
# - ***toppar directory***: contains the force field topology and parameter files
# - ***traceback directory***: contains traceback.tsv, which links all models to see which model originates from which throughout all steps of the workflow.
# - ***log file***: text file with information about the docking process and duration of the run
#
# Each ***sampling/refinement/selection*** module will contain **PDB files**. For example, the 09_seletopclusts directory contains the **selected models** from each cluster. The **clusters** in that directory are numbered based on their rank, i.e. cluster_1 refers to the top-ranked cluster. Information about the origin of these files can be found in that directory in the seletopclusts.txt file.
#
# ***

# %%
# Listing directories of the final results
# !ls {haddock_wf_data}

# %%
# Listing -seletopclust- directory content (Note the generated PDB models)
# !ls {haddock_wf_data}/09_seletopclusts

# %%
# Listing ANALYSES directories of the final results
# !ls {haddock_wf_data}/analysis

# %%
# Listing -seletopclusts- directory content of the final ANALYSES results
# !ls {haddock_wf_data}/analysis/7_caprieval_analysis

# %% [markdown]
# ***
#
# ## Questions & Comments
#
# Questions, issues, suggestions and comments are really welcome!
#
# * GitHub issues:
#     * [https://github.com/bioexcel/biobb](https://github.com/bioexcel/biobb)
#
# * BioExcel forum:
#     * [https://ask.bioexcel.eu/c/BioExcel-Building-Blocks-library](https://ask.bioexcel.eu/c/BioExcel-Building-Blocks-library)
